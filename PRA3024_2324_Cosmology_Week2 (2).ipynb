# %% [markdown]
# # <font color='deepskyblue'>Cosmology MCMC notebook </font>

# %% [markdown]
# ## <font color='deepskyblue'>Preliminaries</font>

# %%
# Install required packages (if not available on server)
try:
  import getdist
except:
  # !pip install getdist
  import getdist

# Load required packages
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.integrate as integrate

# import pylab
import getdist, IPython, time
from numpy import random

# from IPython.display import Image
from getdist import plots, MCSamples, loadMCSamples

# just for printing! calculations should be performed with machine precision
# %precision 3
# Out:
# Collecting getdist
#   Downloading getdist-1.4.7.tar.gz (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.1/826.1 kB 6.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from getdist) (1.25.2)
# Requirement already satisfied: matplotlib!=3.5.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from getdist) (3.7.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from getdist) (1.11.4)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from getdist) (6.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from getdist) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.5.0,>=2.2.0->getdist) (1.16.0)
# Building wheels for collected packages: getdist
#   Building wheel for getdist (pyproject.toml) ... done
#   Created wheel for getdist: filename=getdist-1.4.7-py3-none-any.whl size=810432 sha256=071f8884e27b2cc3e523d74412b461d5bb2c9aacbe24670802317e4f4a65b9a5
#   Stored in directory: /root/.cache/pip/wheels/11/3e/8d/93c9494b4587d95165f805b376a4c7ed3ae670eb3cf7397389
# Successfully built getdist
# Installing collected packages: getdist
# Successfully installed getdist-1.4.7
# '%.3f'

# %% [markdown]
# <font color='tomato'>
# (NB: The equations you'll directly need to build your code are those $\boxed{\text{with a box around}}$)
# </font>
#
# ## <font color='deepskyblue'>The $\Lambda$CDM Model</font>
#
# The Lambda-Cold-Dark-Matter ($\Lambda$CDM) Model is our concordance cosmological model. It postulates a Universe that behaves according to **General Relativity**, filled with **baryons** (protons, neutrons - the stuff we and stars are made of!), **Cold Dark Matter (CDM)** and a **Cosmological Constant** $\Lambda$.
#
# The expansion of the Universe is best described in terms of the **scale factor** $a$ (the "radius" of the Universe, conventionally set to 1 today) and the **Hubble rate** $H$. While photons (light rays) travel in the expanding universe they get redshifted, and this redshift is directly related to the size of the Universe when the photon was emitted compared to today:
#
# $$ \frac{\lambda_{\rm obs}}{\lambda_{\rm em}} \equiv 1 + z_{\rm em} = \frac{1}{a_{\rm em}}$$
#
#
# In the $\Lambda$CDM model (and at late enough times), this additionally simplifies to
#
# $$
# \begin{gathered}
# \boxed{
# H^2 = H_0^2\left[\Omega_\Lambda + \Omega_m (1+z)^3 + \Omega_k (1+z)^2\right]
# }
# \\
# \boxed{
# \Omega_m + \Omega_\Lambda + \Omega_k = 1
# }
# \end{gathered}
# \tag{1}
# $$
#
# $H_0$ is the value of the Hubble rate *today*, and the parameters $\Omega_m$, $\Omega_\Lambda$ and $\Omega_k$ are dimensionless quantities indicating how much of the present expansion of the Universe is due to (non-relativistic) matter, cosmological constant $\Lambda$, and spatial curvature $k$. Note that the three $\Omega$'s are *not independent* (their sum is 1) and that we grouped together the contribution of baryons and CDM,
#
# $$
# \Omega_m = \Omega_{\rm CDM} + \Omega_{\rm b}
# $$
#
# and that we have evidence that independent evidence that $\Omega_b \approx 5$\%. NB: only $\Omega_m \geq 0$ makes physical sense, while in principle both $\Omega_\Lambda$ and $\Omega_k$ can be negative.
#
# The present Hubble rate is conventionally parametrised in terms of the dimensionless $h$:
#
# $$
# \boxed{
#   H_0 \equiv 100\,h\,\frac{\rm km}{\rm s\,Mpc}
# }
# \tag{2}
# $$
#
# where Mpc = Megaparsec and [parsec](https://en.wikipedia.org/wiki/Parsec) equals to about $3.26$ light years or $3.086 \cdot 10^{16}$ m.
#
# In essence, these equations give us the relation between *what exists in the Universe* and *how the Universe expanded*. Measure one, I can tell you the other. This is precisely what we aim to do!
#
# Time to define the function $H(z)$. Don't forget to include the useful parameters as arguments of the function, and to define `parsec`.

# %%
# Hubble rate: look at equations (1) and (2) for the definition!
def Hubble(z, OmegaL, OmegaM, H0):
  OmegaK = 1. - OmegaL - OmegaM
  H = H0 * np.sqrt((OmegaL + OmegaM * (1+z)**3 + OmegaK * (1+z)**2))
  return H # <--- YOUR CODE GOES HERE!

# %%
# %matplotlib inline
OmegaL=0.7
OmegaM=0.3
H0=0.7

zs=np.arange(0,1.4,0.1)
Hs=[]
for z in zs:
  Hs += [Hubble(z, OmegaL, OmegaM, H0)]
plt.scatter(zs,Hs)
plt.xlabel('z')
plt.ylabel('H(z)')
plt.show()

# %% [markdown]
# ## <font color='deepskyblue'>Supernovae Ia</font>
#
# In order to track the expansion of the Universe, we will look at Supernovae type Ia observations. SNIa are formed when a *white dwarf* accretes matter from a companion until it reaches a critical mass of about $1.44 M_\odot$ (solar masses), after which it explodes **at always the same luminosity** $L_{\rm SN}$. Therefore, the observed [magnitude](https://en.wikipedia.org/wiki/Magnitude_(astronomy)) is only a function of their [**luminosity distance**](https://en.wikipedia.org/wiki/Distance_measures_(cosmology)) from Earth, defined as the ratio of the intrinsic luminosity $L_{\rm SNIa}$ and the measured *surface brightness* $\Phi$ (energy per unit time per unit area)
#
# $$ d_L\equiv \frac{L_{\rm SN}}{4\pi \Phi} $$
#
# We can express the luminosity distance in terms of the Hubble rate:
#
# $$
# \boxed{
# d_L(z) = \frac{c}{H_0}(1+z) \times
# \begin{cases}
#     \cfrac{1}{\sqrt{\Omega_k}} \,\sinh\left(\sqrt{\Omega_k}\,D(z)\right) & \Omega_k > 0
#     \\[.5em]
#     D(z) & \Omega_k = 0
#     \\[.5em]
#     \cfrac{1}{\sqrt{-\Omega_k}} \,\sin\left(\sqrt{-\Omega_k}\,D(z)\right) & \Omega_k < 0
# \end{cases}
# \qquad\qquad
# D(z) \equiv H_0\int_0^z \frac{{\rm d}Z}{H(Z)}
# }
# \tag{3}
# $$
#
# where $c$ is the speed of light: $c \simeq 2.998 \cdot 10^{5}$ km/s.
#
# Clearly, there exists a relation between $d_L(z)$ and $H(z)$, so the luminosity distance is a useful measure of the Universe expansion history.
# In practice, however, the actual observable for [Supernovae Type Ia](https://en.wikipedia.org/wiki/Type_Ia_supernova) (or SNIa) is the [distance modulus](https://en.wikipedia.org/wiki/Distance_modulus) $\mu$, defined as the difference between the *apparent magnitude* $m$ and the *absolute magnitude* $M$:
#
# $$
# \boxed{
# \mu(z) \equiv m(z) - M \equiv 5 \log_{10} \frac{d_L(z)}{10\,\text{pc}}
# }
# \tag{4}
# $$
#
# We can create the function `dL(z, h, Omega_m, Omega_Lambda)`. You can also pass the function `Hubble` as an argument: `dL(z, Hubble, Omega_m, Omega_Lambda)`. Additionally, you can create $D(z)$ for your convenience.
#
# Note that you need to integrate the function $H(z)$, so write your own quick-and-easy numerical integrator, for example implementing the [trapezoidal rule](https://en.wikipedia.org/wiki/Trapezoidal_rule) or your favourite alternative, or [look up the pre-written methods](https://docs.scipy.org/doc/scipy/tutorial/integrate.html). Make sure it returns $d_L$ in parsecs and that it uses $H_0$ measured in units of 100 km/s/Mpc (which we called $h$).

# %%
c = 2.998e5 # <--- Choose your favourite units, but make sure you're consistent! in km per second
# Integrate 1/H from x = 0 to x = z
def D(z,OmegaL, OmegaM, H0): # Yes, you can pass a function as argument!
    # This is how you integrate with integrate.quad;
    # (...)[0] gives the result of the integral; (...)[1] is the error estimate; see manual for details
    return H0*integrate.quad(lambda x: 1/Hubble(x, OmegaL, OmegaM, H0), 0., z)[0]

# Let's just print a sample result
#def Hubble(z, h, OmegaL, OmegaM):
#    display(D(1., Hubble, OmegaM, OmegaL, H0))
OmegaK = 1. - OmegaL - OmegaM

#Multipying by 10^4 to convert from Mpc to pc
def dL(z, H0, OmegaL, OmegaM): # luminosity distance, use eq.(3)
  Dz=D(z, OmegaM, OmegaL, H0)
  if OmegaK>0:
    return 10**4*(c/(H0))*(1+z)*(1/np.sqrt(OmegaK))*np.sinh(np.sqrt(OmegaK)*Dz)
  elif OmegaK==0:
    return 10**4*(c/(H0))*(1+z)*Dz
  elif OmegaK<0:
    return 10**4*(c/(H0))*(1+z)*(1/np.sqrt(-OmegaK))*np.sin(np.sqrt(-OmegaK)*Dz)

# %%
# Test our function!

OmegaL = 0.7
OmegaM = 0.3
H0 = 0.7

zs = np.arange(0, 1.4, 0.1)
dLs = []
for z in zs :
    dLs += [dL(z, OmegaL, OmegaM, H0)]

plt.scatter(zs, dLs)
plt.xlabel('z')
plt.ylabel('dL(z)')
plt.show()

# %%
def mu(z, OmegaL, OmegaM, H0): # distance modulus -- use eq.(4)
    return 5*np.log10(dL(z, OmegaL, OmegaM, H0)/10) # <--- YOUR CODE GOES HERE!

# %%
# Test our function!

OmegaL = 0.7
OmegaM = 0.3
H0 = 0.7

zs = np.arange(0.1, 1.4, 0.1)
mus = []
for z in zs :
    mus += [mu(z, OmegaL, OmegaM, H0)]

plt.scatter(zs, mus, marker='D')
plt.xlabel('z')
plt.ylabel('${\mu}$(z)')
plt.show()

# %% [markdown]
# ## <font color='deepskyblue'>The Union2.1 Compilation</font>
#
# Our source of data is from [Union2.1](http://supernova.lbl.gov/Union/). It is a collection of $580$ SNIa, each observation is comprised of redshift $z$
# Our goal today is to use SNIa measurements to constrain the parameters ($h, \Omega_\Lambda, \Omega_m$).
#
# In essence, we can calculate for each redshift the theoretical value of $\mu$ using this equation with the expression for $d_L(z)$ and our model of choice $H(z)$ -- note that we will need to perform a numerical integral! -- and compare this value with observations. A different model would amount to changing the theoretical value of $H(z)$.
#
# Let us start by importing and plotting the data:

# %%
dataloc = "http://supernova.lbl.gov/Union/figures/SCPUnion2.1_mu_vs_z.txt"

# Read in data as numpy array.
# Format is [name, redshift, magnitude, magnitude error, and another number?]
data = np.genfromtxt(dataloc)

# Print the first line as an example. (Note that genfromtxt turns the names into 'Not A Number')
display(data[0])
# Out:
# array([      nan, 2.849e-02, 3.535e+01, 2.239e-01, 1.284e-01])

# %%
# Extract the redshifts (zs), distance modulus (dist_mod) and magnitude estimated errors (err_dist_mod)
# Data are in columns, so we either slice it by columns: arr[:,n]...
zs = data[:,1] # redshift

# ...or transpose the array and then slice by row: arr_transposed[n]
distance_modulus = data.T[2] # distance modulus
error_distance_modulus = data.T[3] # errors on distance modulus = sigmas

# %%
# Let's look at the data, just for fun.
# We can look both at the raw data (distance modulus) or calculate the luminosity distance
# Note that Numpy allows us to manipulate whole arrays at once with something like:
#     array_2 = some_function_of(array_1)

#luminosity distance in pc
luminosity_distance_pc = 10. * 10.**(distance_modulus / 5.)

# luminosity distance in Mpc
luminosity_distance_Mpc = 1.E-5 * 10.**(distance_modulus / 5.)

# and the error on that distance:
error_luminosity_distance_Mpc = 5. * (10.**((distance_modulus + error_distance_modulus)/5.-6.) - 10.**((distance_modulus - error_distance_modulus)/5.-6.))

# %%
#This code was used to get a better understanding of the data by visiualizing it.
import pandas as pd

dataframe = pd.DataFrame({"redshift":zs,
                   "distance_modulus":distance_modulus,
                   "distance_modulus_error":error_distance_modulus,
                   "Luminosity distance pc":luminosity_distance_pc,
                   "luminosity_distance_Mpc":luminosity_distance_Mpc ,
                   "error_luminosity_distance_Mpc":error_luminosity_distance_Mpc})
dataframe.describe()
# Out:
#          redshift  distance_modulus  distance_modulus_error  \
# count  580.000000        580.000000              580.000000
# mean     0.361631         40.028495                0.222955
# std      0.327353          3.195595                0.126012
# min      0.015000         33.824609                0.084144
# 25%      0.054550         36.920249                0.151396
# 50%      0.294028         40.884198                0.189029
# 75%      0.551700         42.517637                0.241556
# max      1.414000         45.410744                1.006812
#
#        Luminosity distance pc  luminosity_distance_Mpc  \
# count            5.800000e+02               580.000000
# mean             2.209307e+09              2209.306847
# std              2.317339e+09              2317.338603
# min              5.819984e+07                58.199838
# 25%              2.422198e+08               242.219796
# 50%              1.502674e+09              1502.674447
# 75%              3.188077e+09              3188.076719
# max              1.208228e+10             12082.277932
#
#        error_luminosity_distance_Mpc
# count                     580.000000
# mean                      289.336492
# std                       441.344011
# min                         4.207930
# 25%                        16.661538
# 50%                       120.529500
# 75%                       398.462205
# max                      3550.896956

# %%
# Recommendation: you might want to try your functions here, and check that for Omega_m = 0.3 and Omega_L = 0.7 you get a decent match to the data
# %matplotlib inline

plt.subplots(1, 2, figsize=(12, 4))

# Plot distance modulus versus redshift (original data)
plt.subplot(1, 2, 1)
plt.xlabel("Redshift")
plt.ylabel("Distance Modulus")
plt.errorbar(zs, distance_modulus,\
             yerr=error_distance_modulus,\
             fmt='o',\
             color='indigo',\
             ecolor='deeppink',\
             markersize=4)

# Plot luminosity distance versus redshift
plt.subplot(1, 2, 2)
plt.xlabel("Redshift")
plt.ylabel("Luminosity Distance [Mpc]")
plt.errorbar(zs, luminosity_distance_Mpc,\
             yerr=error_luminosity_distance_Mpc,\
             fmt='o',\
             color='indigo',\
             ecolor='deeppink',\
             markersize=4)

plt.show()

# %%
# %matplotlib inline

plt.figure(figsize=(10,7))
plt.xlabel('Redshift')
plt.ylabel('Distance modulus')
plt.errorbar(zs, distance_modulus, yerr=data[:,3], fmt='o', markersize='5', color='indigo', ecolor='deeppink')

modelzs = np.arange(0.05, 1.5, 0.05)
modelmus = []
for z in modelzs :
    modelmus += [mu(z, OmegaL, OmegaM, H0)]

plt.plot(modelzs, modelmus, linewidth=4, color='cyan')
plt.show()

# %% [markdown]
# ## <font color='deepskyblue'>Bayes' Theorem: Likelihood, Prior, Posterior (and Evidence...)</font>
#
# The **conditional probability of A given that B is true** is denoted with $P(A|B)$ (read: *probability of A given B*).
# Did A happen? Then B has probability $P(B|A)$ of happening.
#
# [**Bayes' Theorem**](https://en.wikipedia.org/wiki/Bayes%27_theorem) is simply a reflection of the symmetry of the concept of joint probability:
#
# $$
# P(A|B)P(B) = P(B|A)P(A)
# $$
#
# In physics, our goal is often to determine how likely the values of some parameters $\theta$ are, given how well they reproduce the data $D$.
# We write Bayes' theorem in the following equivalent form:
#
# $$
# P(\theta | D) = \frac{P(D|\theta)P(\theta)}{P(D)}
# $$
#
# The various terms conventionally take the names:
#
# $$
# \begin{aligned}
# P(\theta | D) & && \text{Posterior}
# \\
# P(D | \theta)& && \text{Likelihood}
# \\
# P(\theta) & && \text{Prior}
# \\
# P(D) & && \text{Evidence}
# \end{aligned}
# $$
#
# ### <font color='deepskyblue'>Prior</font>
#
# The *prior* quantifies our degree of prior belief in the model parameters. It can contain the results of previous experiments, or theoretical considerations (for instance, that certain parameters cannot be negative, etc.).
#
# We can have *strong priors* about something - the Sun still existing at night, see the comic below - or not.
# When we do *not* have compelling prior knowledge about a parameter, we generally use a *non-informative* prior probability distribution, most often related to the [uniform distribution](https://en.wikipedia.org/wiki/Continuous_uniform_distribution)
#
# $$
# \begin{aligned}
#     \text{Uniform} & && \theta \in \text{Uniform}[\theta_{\rm min}, \theta_{\rm max}]
#     \\
#     \text{Log Uniform} & && \log\theta \in \text{Uniform}[\log\theta_{\rm min}, \log\theta_{\rm max}]
# \end{aligned}
# $$
#
# You may sometimes hear that "the prior doesn't matter". While this is not strictly true, it is however true that in many instances the *likelihood* depends more dramatically on the parameters and will have a dominating contribution to the posterior. You are more than welcome to try different priors for the model parameters and see if and how your results change.
#
# ### <font color='deepskyblue'>Likelihood</font>
#
# The measure of how well our model reproduces the data is the **likelihood** $\mathcal L$. For normal (=Gaussian), uncorrelated data $\mu_i$ with errors $\sigma_i$ ($i = \{1,580\}$), the likelihood is related to the famous [**chi-squared**](https://en.wikipedia.org/wiki/Chi-square_distribution) via
#
# $$
# P(D | \theta) \equiv \mathcal L = \exp\left(-\frac{\chi^2}{2}\right)
# \qquad
# \qquad
# \boxed{
# \chi^2 \equiv \sum_{i=1}^{580} \frac{\left(\mu_i^{(\rm theor)} - \mu_i^{(\rm obs)}\right)^2}{\sigma_i^2}
# }
# \tag{5}
# $$
#
# A *high likelihood* corresponds to a *low chi squared*.
#
# In principle, we could attack the problem brute-force: create a grid of values for $h$, $\Omega_m$, $\Omega_\Lambda$, calculate the likelihood for each combination, and create a profile for the likelihood.
#
# In practical cases, however, this is not only sub-optimal but sometimes **impossible**. Think of complicated models with 20+ free parameters (this is not unheard of, by the way). Even a very coarse grained grid of 100 values for each parameter would result in more than $10^{40}$ (!!!) different parameter combination to be tested. You can probably understand why this is undesirable.
#
# ### <font color='deepskyblue'>Evidence</font>
#
# This is the tricky bit. The evidence, which is "*the probability of observing certain data*", is not something that is easy to evaluate or interpret. This looks like a serious limitation to finding the:
#
#
# ### <font color='deepskyblue'>Posterior</font>
#
# What does the data tell us about the model parameters? The answer is the *posterior probability distribution*, often (but not necessarily) expressed as (average $\pm$ standard deviation)
#
# $$
# \theta_i = \bar\theta_i \pm \sigma_i
# $$
#
# In other words, the posterior tells us how likely it is for the model parameters to have certain values, *given that we observe the data* $D$.
#
# *This is the final goal of our analysis!*
#
# <br>
#
# ![title](http://1.bp.blogspot.com/-tTx4HDejSww/ULcTeK9_V_I/AAAAAAAAA8g/PCYOH-eXGbk/s1600/frequentists_vs_bayesians.png)
# ![title](https://i.redd.it/5r0hwixt0m931.jpg)

# %% [markdown]
# ## <font color='deepskyblue'>Markov-Chain Monte Carlo</font>
#
# Markov-Chain Monte Carlo techniques are a class of methods to sample a probability distribution $P(x)$ - in our case $P(\theta | D)$ - provided that we can calculate a density $\mathcal F(x)$ **that is proportional to it** - in our case $P(\theta)P(D|\theta)$ = likelihood $\times$ prior. Among these, a very popular one is the [**Metropolis-Hastings**](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm) algorithm, which is what we will use.
#
# Schematically, the algorithm works as follows:
# * Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and calculate the $\mathcal F_{\rm old}$
# * Propose a new set of parameters $\theta_{\rm prop}$, calculate the new corresponding $\mathcal F_{\rm prop}$. How you propose the new parameters is not essential as long as the probability of going from one set of parameters to the next is the same as the inverse: $P(\theta_a \to \theta_b) = P(\theta_b \to \theta_a)$. For this, we normally take Gaussian displacements with some (relatively small) standard deviation.
# * Compare the new and old likelihoods-priors:
#     * If $\mathcal F_{\rm prop} > \mathcal F_{\rm old}$, accept the step: $\theta_{\rm new} = \theta_{\rm prop}$
#     * Otherwise, accept with probability $P_{\rm accept} = \mathcal F_{\rm prop}/\mathcal F_{\rm old}$
# * If accepted, $\theta_{\rm new} = \theta_{\rm prop}$ and record the step; otherwise, $\theta_{\rm new} = \theta_{\rm old}$ (no re-recording)
# * Update $\theta_{\rm old} = \theta_{\rm new}$
# * Repeat
#
# The MC chain keeps going until the desired number of steps or, ideally, when a suitable convergence test, like for example the [Gelman-Rubin test](https://bookdown.org/rdpeng/advstatcomp/monitoring-convergence.html), is satisfied.
# Today we will just set a limit to the total number of steps, but please feel free to implement and test your favourite convergence test!
#
# Looking at equation (5), you can convince yourself that
# $$
# \frac{\mathcal L_a}{\mathcal L_b} = \exp\left(\frac{\chi_b^2 - \chi_a^2}{2}\right)
# $$
#
# (This is useful because $\chi^2$ can be large, so we want to avoid the likelihoods evaluating to `0.` -- computers don't like dividing by zero, unfortunately)
#
#
# * <font color="deepskyblue"> Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and the corresponding chi squared $\chi_{\rm old}^2$ (to be clear, for us this implies calculating a series of 580 integrals and comparing each with the observed values) </font>
# * <font color="deepskyblue"> Propose new parameters $\theta_{\rm prop}$ and calculate the corresponding chi squared $\chi_{\rm prop}^2$</font>
# * <font color="deepskyblue"> Draw a random number $r \in [0,1]$</font>
# * <font color="deepskyblue"> Accept the step if
# $$
# r < \exp\left(\frac{\chi_{\rm old}^2 - \chi_{\rm prop}^2}{2}\right) \frac{P(\theta)_{\rm prop}}{P(\theta)_{\rm old}}
# $$</font>
#     * <font color="deepskyblue"> If accepted, update $\theta_{\rm old} = \theta_{\rm prop}$</font>
#     * <font color="deepskyblue">If you want, you can keep a record of the best fit (lowest $\chi^2$), but this is not the specific purpose of MCMC! We are exploring the parameter space and sampling a _posterior distribution_, not just finding the best fit</font>
# * <font color="deepskyblue"> Record the step - including **re-recording** if the step was not accepted! </font>
# * <font color="deepskyblue"> Repeat</font>

# %%
import numpy as np

# Function to calculate chi-squared
def chi_squared(h, Omega_M, Omega_L, dataframe):
    chi_squared_total = 0
    for i in range(len(dataframe)):
        redshift = dataframe['redshift'][i]
        distance_modulus = dataframe['distance_modulus'][i]
        distance_modulus_error = dataframe['distance_modulus_error'][i]
        mu_model = mu(redshift, Omega_L, Omega_M, h)
        chi_squared = (mu_model - distance_modulus) ** 2 / distance_modulus_error ** 2
        chi_squared_total += chi_squared
    return chi_squared_total

# Function to propose new parameters
def new_parameters(h, Omega_M, Omega_L):
    while True:
        h_new = np.random.normal(h, 0.01)
        OmegaM_new = np.random.normal(Omega_M, 0.1)  # Adjusted standard deviation for Omega_M proposal
        OmegaL_new = np.random.normal(Omega_L, 0.01)

        # Ensure proposed parameters are non-negative
        if OmegaM_new >= 0.0 and OmegaL_new >= 0.0 and h_new >= 0.0:
            break

    return h_new, OmegaM_new, OmegaL_new

# Initialize an empty list to store chi-squared values
chi_squared_values = []
Omega_M_list = []
Omega_L_list = []
h_list = []

# Initializing counter for accepted steps
accepted_steps = 0

# Function to perform MCMC iterations
def perform_mcmc(dataframe, N_steps, Omega_M, Omega_L, h):
    global accepted_steps  # declare global variable
    # Initialize best chi-squared value
    chi2_total_best = float('inf')
    # Open file to save MCMC chain
    filename = "MC_Chain_SNIa_Week2.txt"
    with open(filename, "w") as file:
        # Perform MCMC iterations
        for i in range(N_steps):
            # Calculate current chi-squared
            chi_squared_current = chi_squared(h, Omega_M, Omega_L, dataframe)
            # Append current chi-squared value to the list
            chi_squared_values.append(chi_squared_current)

            # Propose new parameters
            h_proposed, OmegaM_proposed, OmegaL_proposed = new_parameters(h, Omega_M, Omega_L)

            # Calculate new chi-squared
            chi_squared_proposed = chi_squared(h_proposed, OmegaM_proposed, OmegaL_proposed, dataframe)
            #saving all the steps in the lists
            Omega_M_list.append(OmegaM_proposed)
            Omega_L_list.append(OmegaL_proposed)
            h_list.append(h_proposed)
            # Accept or reject the proposal
            if chi_squared_proposed < chi_squared_current or np.random.uniform(0, 1) < np.exp((chi_squared_current - chi_squared_proposed) / 2):
                Omega_M = OmegaM_proposed
                Omega_L = OmegaL_proposed
                h = h_proposed
                accepted = True
                accepted_steps += 1  # Update accepted steps counter
            else:
                accepted = False
            # Save the accepted parameters to file
            file.write(f"{h} {Omega_M} {Omega_L} {accepted}\n")

            # Update best chi-squared if a better point is found
            if chi_squared_current < chi2_total_best:
                Omega_M_best = Omega_M
                Omega_L_best = Omega_L
                h_best = h
                chi2_total_best = chi_squared_current
                chi_squared_values.append(chi_squared_current)
            # Print current parameters
            print(f"Step {i+1}/{N_steps}: Current Chi^2 = {chi_squared_current}, Best Chi^2 = {chi2_total_best}")
            print(f"Current Parameters: Omega_M = {Omega_M}, Omega_L = {Omega_L}, h = {h}")

    return Omega_M_best, Omega_L_best, h_best, chi2_total_best

# Set initial parameter values
Omega_M = 0.2
Omega_L = 0.2
h = 0.2

# Call the MCMC function
Omega_M_best, Omega_L_best, h_best, chi2_total_best = perform_mcmc(dataframe, N_steps=50000, Omega_M=Omega_M, Omega_L=Omega_L, h=h)

# Calculate acceptance ratio
acceptance_ratio = accepted_steps / 50000  # Total steps is 5000
print("Acceptance ratio:", acceptance_ratio)

print("Best parameters:")
print(f"Omega_M: {Omega_M_best}, Omega_L: {Omega_L_best}, h: {h_best}, Best Chi^2: {chi2_total_best}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Current Parameters: Omega_M = 0.11068756984637099, Omega_L = 0.7031663919335716, h = 0.6235131616531404
# Step 47503/50000: Current Chi^2 = 565.5714340453791, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.11068756984637099, Omega_L = 0.7031663919335716, h = 0.6235131616531404
# Step 47504/50000: Current Chi^2 = 565.5714340453791, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.11068756984637099, Omega_L = 0.7031663919335716, h = 0.6235131616531404
# Step 47505/50000: Current Chi^2 = 565.5714340453791, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.11068756984637099, Omega_L = 0.7031663919335716, h = 0.6235131616531404
# Step 47506/50000: Current Chi^2 = 565.5714340453791, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.11068756984637099, Omega_L = 0.7031663919335716, h = 0.6235131616531404
# Step 47507/50000: Current Chi^2 = 565.5714340453791, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.15853220752580877, Omega_L = 0.6991657055407823, h = 0.6222270132846729
# Step 47508/50000: Current Chi^2 = 562.6847122995742, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.15853220752580877, Omega_L = 0.6991657055407823, h = 0.6222270132846729
# Step 47509/50000: Current Chi^2 = 562.6847122995742, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47510/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47511/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47512/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47513/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47514/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47515/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47516/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47517/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47518/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47519/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47520/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47521/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14148178461203686, Omega_L = 0.7030155915950592, h = 0.6119293092143092
# Step 47522/50000: Current Chi^2 = 565.4596860513699, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.10577032517548296, Omega_L = 0.7044174366503432, h = 0.6011684468758107
# Step 47523/50000: Current Chi^2 = 566.9304705714582, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.10577032517548296, Omega_L = 0.7044174366503432, h = 0.6011684468758107
# Step 47524/50000: Current Chi^2 = 566.9304705714582, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.10577032517548296, Omega_L = 0.7044174366503432, h = 0.6011684468758107
# Step 47525/50000: Current Chi^2 = 566.9304705714582, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.10577032517548296, Omega_L = 0.7044174366503432, h = 0.6011684468758107
# Step 47526/50000: Current Chi^2 = 566.9304705714582, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1064898463039703, Omega_L = 0.7058672797520403, h = 0.6080198038037928
# Step 47527/50000: Current Chi^2 = 568.8855415764087, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.09424533317208832, Omega_L = 0.7049006893812952, h = 0.5972301833375632
# Step 47528/50000: Current Chi^2 = 567.6580337590003, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.09424533317208832, Omega_L = 0.7049006893812952, h = 0.5972301833375632
# Step 47529/50000: Current Chi^2 = 567.6580337590003, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.09424533317208832, Omega_L = 0.7049006893812952, h = 0.5972301833375632
# Step 47530/50000: Current Chi^2 = 567.6580337590003, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.09424533317208832, Omega_L = 0.7049006893812952, h = 0.5972301833375632
# Step 47531/50000: Current Chi^2 = 567.6580337590003, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.09424533317208832, Omega_L = 0.7049006893812952, h = 0.5972301833375632
# Step 47532/50000: Current Chi^2 = 567.6580337590003, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.09424533317208832, Omega_L = 0.7049006893812952, h = 0.5972301833375632
# Step 47533/50000: Current Chi^2 = 567.6580337590003, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.09424533317208832, Omega_L = 0.7049006893812952, h = 0.5972301833375632
# Step 47534/50000: Current Chi^2 = 567.6580337590003, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.09424533317208832, Omega_L = 0.7049006893812952, h = 0.5972301833375632
# Step 47535/50000: Current Chi^2 = 567.6580337590003, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1437994448457768, Omega_L = 0.7030042554018906, h = 0.5971432776430081
# Step 47536/50000: Current Chi^2 = 567.2520771358567, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21398188682667646, Omega_L = 0.7009522354619021, h = 0.6097772333278275
# Step 47537/50000: Current Chi^2 = 570.5463600000645, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21398188682667646, Omega_L = 0.7009522354619021, h = 0.6097772333278275
# Step 47538/50000: Current Chi^2 = 570.5463600000645, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21398188682667646, Omega_L = 0.7009522354619021, h = 0.6097772333278275
# Step 47539/50000: Current Chi^2 = 570.5463600000645, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21398188682667646, Omega_L = 0.7009522354619021, h = 0.6097772333278275
# Step 47540/50000: Current Chi^2 = 570.5463600000645, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.13606059217782862, Omega_L = 0.6973810291728483, h = 0.6069779780477798
# Step 47541/50000: Current Chi^2 = 563.5872978049175, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.11941683806928086, Omega_L = 0.7013569346705906, h = 0.6205362994484894
# Step 47542/50000: Current Chi^2 = 564.3571624366806, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.11941683806928086, Omega_L = 0.7013569346705906, h = 0.6205362994484894
# Step 47543/50000: Current Chi^2 = 564.3571624366806, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.11941683806928086, Omega_L = 0.7013569346705906, h = 0.6205362994484894
# Step 47544/50000: Current Chi^2 = 564.3571624366806, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.11941683806928086, Omega_L = 0.7013569346705906, h = 0.6205362994484894
# Step 47545/50000: Current Chi^2 = 564.3571624366806, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17733294199388672, Omega_L = 0.700911028243528, h = 0.6129027546994895
# Step 47546/50000: Current Chi^2 = 565.0223690791161, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17733294199388672, Omega_L = 0.700911028243528, h = 0.6129027546994895
# Step 47547/50000: Current Chi^2 = 565.0223690791161, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17733294199388672, Omega_L = 0.700911028243528, h = 0.6129027546994895
# Step 47548/50000: Current Chi^2 = 565.0223690791161, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17733294199388672, Omega_L = 0.700911028243528, h = 0.6129027546994895
# Step 47549/50000: Current Chi^2 = 565.0223690791161, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17733294199388672, Omega_L = 0.700911028243528, h = 0.6129027546994895
# Step 47550/50000: Current Chi^2 = 565.0223690791161, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.13287782927289254, Omega_L = 0.7023883593286956, h = 0.6399569845750915
# Step 47551/50000: Current Chi^2 = 564.7862978195997, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.13287782927289254, Omega_L = 0.7023883593286956, h = 0.6399569845750915
# Step 47552/50000: Current Chi^2 = 564.7862978195997, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.13287782927289254, Omega_L = 0.7023883593286956, h = 0.6399569845750915
# Step 47553/50000: Current Chi^2 = 564.7862978195997, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.13287782927289254, Omega_L = 0.7023883593286956, h = 0.6399569845750915
# Step 47554/50000: Current Chi^2 = 564.7862978195997, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21403799535061435, Omega_L = 0.6986736224545849, h = 0.6279386153475984
# Step 47555/50000: Current Chi^2 = 564.1339812049466, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2364350310250419, Omega_L = 0.6929503483813256, h = 0.636290467847477
# Step 47556/50000: Current Chi^2 = 565.6397803884237, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2364350310250419, Omega_L = 0.6929503483813256, h = 0.636290467847477
# Step 47557/50000: Current Chi^2 = 565.6397803884237, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2364350310250419, Omega_L = 0.6929503483813256, h = 0.636290467847477
# Step 47558/50000: Current Chi^2 = 565.6397803884237, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2364350310250419, Omega_L = 0.6929503483813256, h = 0.636290467847477
# Step 47559/50000: Current Chi^2 = 565.6397803884237, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2364350310250419, Omega_L = 0.6929503483813256, h = 0.636290467847477
# Step 47560/50000: Current Chi^2 = 565.6397803884237, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2364350310250419, Omega_L = 0.6929503483813256, h = 0.636290467847477
# Step 47561/50000: Current Chi^2 = 565.6397803884237, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47562/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47563/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47564/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47565/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47566/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47567/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47568/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47569/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47570/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47571/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47572/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47573/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47574/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47575/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.18658706859800422, Omega_L = 0.7015486991035713, h = 0.6345194418943075
# Step 47576/50000: Current Chi^2 = 564.2106773902265, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.12708437890101154, Omega_L = 0.7040813929727486, h = 0.6200171715985339
# Step 47577/50000: Current Chi^2 = 565.9257457323315, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.12708437890101154, Omega_L = 0.7040813929727486, h = 0.6200171715985339
# Step 47578/50000: Current Chi^2 = 565.9257457323315, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.12708437890101154, Omega_L = 0.7040813929727486, h = 0.6200171715985339
# Step 47579/50000: Current Chi^2 = 565.9257457323315, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.12708437890101154, Omega_L = 0.7040813929727486, h = 0.6200171715985339
# Step 47580/50000: Current Chi^2 = 565.9257457323315, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47581/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47582/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47583/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47584/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47585/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47586/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47587/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47588/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47589/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47590/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47591/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47592/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47593/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47594/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47595/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47596/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47597/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47598/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47599/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47600/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47601/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47602/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47603/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47604/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47605/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47606/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47607/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47608/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47609/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16158878828380108, Omega_L = 0.695655838871944, h = 0.6222759718634799
# Step 47610/50000: Current Chi^2 = 564.7039738440621, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47611/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47612/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47613/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47614/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47615/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47616/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47617/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47618/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47619/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47620/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47621/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16772572553535062, Omega_L = 0.6989970395545454, h = 0.6269861226504095
# Step 47622/50000: Current Chi^2 = 562.5888107692156, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47623/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47624/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47625/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47626/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47627/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47628/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47629/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47630/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47631/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47632/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47633/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47634/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47635/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47636/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47637/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47638/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47639/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47640/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47641/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47642/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47643/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47644/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47645/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47646/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47647/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47648/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47649/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.16203121478848415, Omega_L = 0.701095616899981, h = 0.6353633362144813
# Step 47650/50000: Current Chi^2 = 563.1235219738907, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47651/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47652/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47653/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47654/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47655/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47656/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47657/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47658/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47659/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47660/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47661/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47662/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47663/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47664/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47665/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47666/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47667/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1523424060632353, Omega_L = 0.7014445967080712, h = 0.6381915184199728
# Step 47668/50000: Current Chi^2 = 563.4778207207538, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20963766098583708, Omega_L = 0.6971274032958058, h = 0.6308144407305262
# Step 47669/50000: Current Chi^2 = 562.984538441063, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20963766098583708, Omega_L = 0.6971274032958058, h = 0.6308144407305262
# Step 47670/50000: Current Chi^2 = 562.984538441063, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20963766098583708, Omega_L = 0.6971274032958058, h = 0.6308144407305262
# Step 47671/50000: Current Chi^2 = 562.984538441063, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20963766098583708, Omega_L = 0.6971274032958058, h = 0.6308144407305262
# Step 47672/50000: Current Chi^2 = 562.984538441063, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20963766098583708, Omega_L = 0.6971274032958058, h = 0.6308144407305262
# Step 47673/50000: Current Chi^2 = 562.984538441063, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20963766098583708, Omega_L = 0.6971274032958058, h = 0.6308144407305262
# Step 47674/50000: Current Chi^2 = 562.984538441063, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20963766098583708, Omega_L = 0.6971274032958058, h = 0.6308144407305262
# Step 47675/50000: Current Chi^2 = 562.984538441063, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20963766098583708, Omega_L = 0.6971274032958058, h = 0.6308144407305262
# Step 47676/50000: Current Chi^2 = 562.984538441063, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23708567330485605, Omega_L = 0.6933055196602195, h = 0.6299292891971358
# Step 47677/50000: Current Chi^2 = 565.2970641020573, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23708567330485605, Omega_L = 0.6933055196602195, h = 0.6299292891971358
# Step 47678/50000: Current Chi^2 = 565.2970641020573, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23708567330485605, Omega_L = 0.6933055196602195, h = 0.6299292891971358
# Step 47679/50000: Current Chi^2 = 565.2970641020573, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23708567330485605, Omega_L = 0.6933055196602195, h = 0.6299292891971358
# Step 47680/50000: Current Chi^2 = 565.2970641020573, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47681/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47682/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47683/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47684/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47685/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47686/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47687/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47688/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19966830986985434, Omega_L = 0.6963062218749964, h = 0.6335482750550705
# Step 47689/50000: Current Chi^2 = 563.0079505537124, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21446676827581268, Omega_L = 0.6996415826857934, h = 0.6437557724453197
# Step 47690/50000: Current Chi^2 = 563.3879855832923, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47691/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47692/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47693/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47694/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47695/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47696/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47697/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47698/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47699/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47700/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47701/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47702/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47703/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21252364243367386, Omega_L = 0.6993046622026218, h = 0.639784774228966
# Step 47704/50000: Current Chi^2 = 563.3561308123344, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47705/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47706/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47707/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47708/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47709/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47710/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47711/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47712/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.21224874910792954, Omega_L = 0.6979348619665832, h = 0.6382068980824033
# Step 47713/50000: Current Chi^2 = 562.8383984852629, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17812861730605087, Omega_L = 0.7026034561288637, h = 0.6429369112348751
# Step 47714/50000: Current Chi^2 = 564.2937840335401, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17812861730605087, Omega_L = 0.7026034561288637, h = 0.6429369112348751
# Step 47715/50000: Current Chi^2 = 564.2937840335401, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17812861730605087, Omega_L = 0.7026034561288637, h = 0.6429369112348751
# Step 47716/50000: Current Chi^2 = 564.2937840335401, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17812861730605087, Omega_L = 0.7026034561288637, h = 0.6429369112348751
# Step 47717/50000: Current Chi^2 = 564.2937840335401, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17812861730605087, Omega_L = 0.7026034561288637, h = 0.6429369112348751
# Step 47718/50000: Current Chi^2 = 564.2937840335401, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17812861730605087, Omega_L = 0.7026034561288637, h = 0.6429369112348751
# Step 47719/50000: Current Chi^2 = 564.2937840335401, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17812861730605087, Omega_L = 0.7026034561288637, h = 0.6429369112348751
# Step 47720/50000: Current Chi^2 = 564.2937840335401, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17812861730605087, Omega_L = 0.7026034561288637, h = 0.6429369112348751
# Step 47721/50000: Current Chi^2 = 564.2937840335401, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14579148248856408, Omega_L = 0.7054552191873168, h = 0.635078087969729
# Step 47722/50000: Current Chi^2 = 567.5663349754027, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.14579148248856408, Omega_L = 0.7054552191873168, h = 0.635078087969729
# Step 47723/50000: Current Chi^2 = 567.5663349754027, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1780176954508366, Omega_L = 0.7026505419638637, h = 0.6416893174086028
# Step 47724/50000: Current Chi^2 = 564.4295062538089, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47725/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47726/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47727/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47728/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47729/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47730/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47731/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47732/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47733/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47734/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47735/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47736/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47737/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47738/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2782425345963626, Omega_L = 0.691330342701757, h = 0.6369978401660419
# Step 47739/50000: Current Chi^2 = 568.3756088570749, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.27763823167019114, Omega_L = 0.69752650860901, h = 0.640865371592281
# Step 47740/50000: Current Chi^2 = 568.898240638122, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23241759230430165, Omega_L = 0.6926271918297006, h = 0.64122146386511
# Step 47741/50000: Current Chi^2 = 566.3001746936303, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23241759230430165, Omega_L = 0.6926271918297006, h = 0.64122146386511
# Step 47742/50000: Current Chi^2 = 566.3001746936303, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47743/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47744/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47745/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47746/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47747/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47748/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47749/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47750/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47751/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20411229639329762, Omega_L = 0.701431397706679, h = 0.6307675525014714
# Step 47752/50000: Current Chi^2 = 566.0368668123631, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.27698096610778844, Omega_L = 0.6983364163072826, h = 0.6483563903818558
# Step 47753/50000: Current Chi^2 = 568.3972013737359, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22020980369907872, Omega_L = 0.7011832852019795, h = 0.628723243115098
# Step 47754/50000: Current Chi^2 = 568.0455926427467, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22020980369907872, Omega_L = 0.7011832852019795, h = 0.628723243115098
# Step 47755/50000: Current Chi^2 = 568.0455926427467, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2465715260024542, Omega_L = 0.6987216227773827, h = 0.6352567993500167
# Step 47756/50000: Current Chi^2 = 566.7899086180634, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2465715260024542, Omega_L = 0.6987216227773827, h = 0.6352567993500167
# Step 47757/50000: Current Chi^2 = 566.7899086180634, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2465715260024542, Omega_L = 0.6987216227773827, h = 0.6352567993500167
# Step 47758/50000: Current Chi^2 = 566.7899086180634, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2465715260024542, Omega_L = 0.6987216227773827, h = 0.6352567993500167
# Step 47759/50000: Current Chi^2 = 566.7899086180634, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2465715260024542, Omega_L = 0.6987216227773827, h = 0.6352567993500167
# Step 47760/50000: Current Chi^2 = 566.7899086180634, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2465715260024542, Omega_L = 0.6987216227773827, h = 0.6352567993500167
# ...
# Step 49916/50000: Current Chi^2 = 563.4484139368637, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17003383672432937, Omega_L = 0.7051436438209788, h = 0.6616174535663635
# Step 49917/50000: Current Chi^2 = 566.14723923791, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.17003383672432937, Omega_L = 0.7051436438209788, h = 0.6616174535663635
# Step 49918/50000: Current Chi^2 = 566.14723923791, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19369485488984572, Omega_L = 0.7022569019797146, h = 0.6803131099785608
# Step 49919/50000: Current Chi^2 = 563.4197857784986, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.19369485488984572, Omega_L = 0.7022569019797146, h = 0.6803131099785608
# Step 49920/50000: Current Chi^2 = 563.4197857784986, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49921/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49922/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49923/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49924/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49925/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49926/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49927/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49928/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.1818750396766618, Omega_L = 0.7016732001600244, h = 0.6703607469863084
# Step 49929/50000: Current Chi^2 = 563.4416484177386, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20547664499196322, Omega_L = 0.7026876153609003, h = 0.6671738441645061
# Step 49930/50000: Current Chi^2 = 563.9169665161177, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.3175121281640217, Omega_L = 0.6989532468251517, h = 0.6809111230445514
# Step 49931/50000: Current Chi^2 = 569.4247984909978, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.3175121281640217, Omega_L = 0.6989532468251517, h = 0.6809111230445514
# Step 49932/50000: Current Chi^2 = 569.4247984909978, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49933/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49934/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49935/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49936/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49937/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49938/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49939/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49940/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49941/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49942/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49943/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49944/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49945/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49946/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49947/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49948/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49949/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49950/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49951/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49952/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49953/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49954/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49955/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49956/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49957/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49958/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49959/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.23614294109578157, Omega_L = 0.700989173049543, h = 0.6816317283714914
# Step 49960/50000: Current Chi^2 = 562.8320584101463, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2251661792506922, Omega_L = 0.6981524669010613, h = 0.6896600353650452
# Step 49961/50000: Current Chi^2 = 563.5004486105615, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2251661792506922, Omega_L = 0.6981524669010613, h = 0.6896600353650452
# Step 49962/50000: Current Chi^2 = 563.5004486105615, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2251661792506922, Omega_L = 0.6981524669010613, h = 0.6896600353650452
# Step 49963/50000: Current Chi^2 = 563.5004486105615, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2251661792506922, Omega_L = 0.6981524669010613, h = 0.6896600353650452
# Step 49964/50000: Current Chi^2 = 563.5004486105615, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2251661792506922, Omega_L = 0.6981524669010613, h = 0.6896600353650452
# Step 49965/50000: Current Chi^2 = 563.5004486105615, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2251661792506922, Omega_L = 0.6981524669010613, h = 0.6896600353650452
# Step 49966/50000: Current Chi^2 = 563.5004486105615, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2251661792506922, Omega_L = 0.6981524669010613, h = 0.6896600353650452
# Step 49967/50000: Current Chi^2 = 563.5004486105615, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49968/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49969/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49970/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49971/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49972/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49973/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49974/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49975/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49976/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49977/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49978/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49979/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49980/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49981/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49982/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49983/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.20350503061349529, Omega_L = 0.6980487349097085, h = 0.6863385461607873
# Step 49984/50000: Current Chi^2 = 565.2873188085753, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2643788977812967, Omega_L = 0.6986931007084808, h = 0.6915311575712765
# Step 49985/50000: Current Chi^2 = 562.4966009895408, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2643788977812967, Omega_L = 0.6986931007084808, h = 0.6915311575712765
# Step 49986/50000: Current Chi^2 = 562.4966009895408, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2643788977812967, Omega_L = 0.6986931007084808, h = 0.6915311575712765
# Step 49987/50000: Current Chi^2 = 562.4966009895408, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22254537302253422, Omega_L = 0.698819955594593, h = 0.675526475569357
# Step 49988/50000: Current Chi^2 = 562.4367134422953, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22254537302253422, Omega_L = 0.698819955594593, h = 0.675526475569357
# Step 49989/50000: Current Chi^2 = 562.4367134422953, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22472381130612754, Omega_L = 0.6986901434184414, h = 0.6824824444797712
# Step 49990/50000: Current Chi^2 = 562.6740120023877, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22472381130612754, Omega_L = 0.6986901434184414, h = 0.6824824444797712
# Step 49991/50000: Current Chi^2 = 562.6740120023877, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22472381130612754, Omega_L = 0.6986901434184414, h = 0.6824824444797712
# Step 49992/50000: Current Chi^2 = 562.6740120023877, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22472381130612754, Omega_L = 0.6986901434184414, h = 0.6824824444797712
# Step 49993/50000: Current Chi^2 = 562.6740120023877, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22472381130612754, Omega_L = 0.6986901434184414, h = 0.6824824444797712
# Step 49994/50000: Current Chi^2 = 562.6740120023877, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22472381130612754, Omega_L = 0.6986901434184414, h = 0.6824824444797712
# Step 49995/50000: Current Chi^2 = 562.6740120023877, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22472381130612754, Omega_L = 0.6986901434184414, h = 0.6824824444797712
# Step 49996/50000: Current Chi^2 = 562.6740120023877, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.22472381130612754, Omega_L = 0.6986901434184414, h = 0.6824824444797712
# Step 49997/50000: Current Chi^2 = 562.6740120023877, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.3163670266649584, Omega_L = 0.6937298390189663, h = 0.6897882813098642
# Step 49998/50000: Current Chi^2 = 566.0274399131993, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2734164606767481, Omega_L = 0.7018693316146863, h = 0.6964605487404083
# Step 49999/50000: Current Chi^2 = 564.8846712416904, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.2734164606767481, Omega_L = 0.7018693316146863, h = 0.6964605487404083
# Step 50000/50000: Current Chi^2 = 564.8846712416904, Best Chi^2 = 562.23214342676
# Current Parameters: Omega_M = 0.24385530614467976, Omega_L = 0.7030908130154452, h = 0.6858493298203544
# Acceptance ratio: 0.14496
# Best parameters:
# Omega_M: 0.2873653701326486, Omega_L: 0.7003060467077267, h: 0.7306844450464458, Best Chi^2: 562.23214342676

# %%
print(accepted_steps)
# Out:
# 7248

# %%
# Plotting chi-squared evolution
plt.plot(chi_squared_values)
plt.ylim(560,600)
plt.xlim(100,50000)
plt.xlabel("Successful Step")
plt.ylabel("$\chi^{2}$")
plt.title("Evolution of $\chi^{2}$ over MCMC Steps")
plt.show()
print("Best parameters:")
print(f"Omega_M: {Omega_M_best}, Omega_L: {Omega_L_best}, h: {h_best}, Best Chi^2: {chi2_total_best}")
# Out:
# Best parameters:
# Omega_M: 0.2873653701326486, Omega_L: 0.7003060467077267, h: 0.7306844450464458, Best Chi^2: 562.23214342676

# %% [markdown]
# The trace plots were added out of curiosity to see how the Omega_M, Omega_L and h develop in time. They were also great help in approximatig which steps are burn ins and have to be cutted off

# %%
import matplotlib.pyplot as plt
#Creatinf a plot that shows the trace of the different components and how they change as the chain keeps going
# Plot the trace for Omega_M
plt.figure(figsize=(10, 6))
plt.subplot(3, 1, 1)
plt.plot(Omega_M_list)
plt.xlabel("Step")
plt.ylabel("Omega_M")
plt.title("Trace Plot for Omega_M")

# Plot the trace for Omega_L
plt.subplot(3, 1, 2)
plt.plot(Omega_L_list)
plt.xlabel("Step")
plt.ylabel("Omega_L")
plt.title("Trace Plot for Omega_L")

# Plot the trace for h
plt.subplot(3, 1, 3)
plt.plot(h_list)
plt.xlabel("Step")
plt.ylabel("h")
plt.title("Trace Plot for h")

plt.tight_layout()
plt.show()

# %%
# plotting the output of the MCMC to the model
plt.figure(figsize=(10,7))
plt.xlabel('Redshift')
plt.ylabel('Distance Modulus')
plt.errorbar(zs, distance_modulus, yerr= error_distance_modulus, fmt='o', markersize=3, color='black', ecolor='deeppink')

modelzs = np.arange(0.05, 1.5, 0.05)
modelmus = []
for z in modelzs :
    modelmus += [mu(z, Omega_L_best, Omega_M_best, h_best)]

plt.plot(modelzs, modelmus, linewidth=4, color='lightskyblue')
plt.show()

# %% [markdown]
# After completion of the programme, your MC chain will (*hopefully*) look something like this: (note the repeated entry!)
#
# `#Omega_m  Omega_L  h`
#
# `0.297     0.703    0.698`
#
# `0.285     0.715    0.701`
#
# `0.285     0.715    0.701`
#
# `0.288     0.712    0.699`
#
# `...`

# %% [markdown]
# ## <font color='deepskyblue'>Plotting: GetDist</font>
#
# We will do the plots with [`GetDist`](https://getdist.readthedocs.io/en/latest/plot_gallery.html).
#
# The plot gallery contains a lot of useful examples, you should be able to read them fairly easily and see which applies to your situation. Look for both (triangle) plots and for parameter estimation.
#
# Note that many `GetDist` functions require arguments of type `MCSamples`; make sure you convert your lists accordingly.
#
# <font color='deepskyblue'>
# Look at your results. Do you obtain $\Omega_\Lambda \neq 0$? To a high degree of significance?
#
# If yes, then my dear friend, you have **DISCOVERED THE ACCELERATED EXPANSION OF THE UNIVERSE AND WON THE NOBEL PRIZE IN PHYSICS 2011!**
# </font>

# %%
import numpy as np
from getdist import MCSamples, plots


#Removing the burn ins from the list
Omega_M_list=Omega_M_list[80:]
Omega_L_list=Omega_L_list[80:]
h_list=h_list[80:]
# converting the list to array
Omega_M = np.array(Omega_M_list)
Omega_L = np.array(Omega_L_list)
h = np.array(h_list)

# You can easily create new np.arrays that are functions of other np.arrays
Omega_k = 1. - Omega_M - Omega_L # calculating the omega k

# Let's define variable names and labels
my_labels = [r'h', r'\Omega_m', r'\Omega_\Lambda', r'\Omega_k']
my_names = ['h', 'Omega_M', 'Omega_L', 'Omega_k']
my_dim = len(my_names) # The number of variables we're plotting

# This creates a higher-dimensional array with all our data, shaped in the appropriate way...
my_samples = np.transpose(np.reshape([h, Omega_M, Omega_L, Omega_k], (my_dim, len(h))))

# ... to create an "MCSamples" data type, which GetDist can use
my_samples = MCSamples(samples=my_samples, labels=my_labels, names=my_names)

# The usual 1-sigma confidence level. You can change to 2- or 3-sigma if you want
conf_level = 0.6827

# This prints a table with the 1D posteriors (confidence levels)
for nam in my_names:
    print(round(my_samples.confidence(nam, (1. - conf_level) / 2., upper=False), 2), \
          " < ", nam , " < ", round(my_samples.confidence(nam, (1. - conf_level) / 2., upper=True), 2),\
          " at ", int(100 * conf_level), "\b% CL")
print("\n")

# Triangle corner plot
j = plots.getSubplotPlotter(subplot_size=3)
j.settings.axes_labelsize = 22
j.settings.axes_fontsize = 16
j.triangle_plot(my_samples, filled=True, title_limit=1, contour_colors=['purple'])
# Out:
# Removed no burn in
# % CL
# % CL
# % CL
# % CL

# %% [markdown]
# ## <font color='deepskyblue'>Further Improvements</font>
#
# There are many ways in which you can improve your code and/or your data visualisation. Some ideas, in random order:
#
# * Modify your priors and compare your results. For instance:
#   * Change to log-flat priors for $h$ and/or $\Omega_m$, namely displace them in log-space instead of linear space:
#   $$
#   \log(h_{\rm new}) = \log(h_{\rm old}) + \delta
#   $$
#   where $\delta$ a random variable of mean 0
#   * Use priors from other cosmological probes, for example the [Planck 2018 results](https://arxiv.org/abs/1807.06209):
#   $$
#   \Omega_m = 0.315 \pm 0.007\,,~\dots
#   $$
# * Monitor acceptance ratio and $\chi^2$ as a function of step count
# * Implement a Gelman-Rubin (or alternative) convergence test
# * Change colours and other properties of your triangle plot
# * Re-plot the data with your theoretical fits: you can try both your best fit, and some $1\sigma$ "error bars"
# * Split your data in redshift bins and repeat the analysis for each bin individually.
# <br> _(What do you notice? Which redshift bins give us the most accurate detection of the cosmological parameters?)_

# %% [markdown]
# In this part i tried to implement log priors

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate chi-squared
def chi_squared(h, Omega_M, Omega_L, dataframe):
    chi_squared_total = 0
    for i in range(len(dataframe)):
        redshift = dataframe['redshift'][i]
        distance_modulus = dataframe['distance_modulus'][i]
        distance_modulus_error = dataframe['distance_modulus_error'][i]
        mu_model = mu(redshift, Omega_L, Omega_M, h)
        chi_squared = (mu_model - distance_modulus) ** 2 / distance_modulus_error ** 2
        chi_squared_total += chi_squared
    return chi_squared_total

# Function to propose new parameters with log-flat priors
def new_parameters(h, Omega_M, Omega_L):
    while True:
        h_new = np.exp(np.log(h) + np.random.normal(0, 0.01))  # Proposal in log-space
        OmegaM_new = np.exp(np.log(Omega_M) + np.random.normal(0, 0.01))  # Proposal in log-space
        OmegaL_new = np.random.normal(Omega_L, 0.01)

        # Ensure proposed parameters are within bounds
        if 0.0 < OmegaM_new < 1.0 and 0.0 < h_new:
            break

    return h_new, OmegaM_new, OmegaL_new

# Initialize an empty list to store chi-squared values, acceptance ratio, and step count
chi_squared_values = []
Omega_M_list = []
Omega_L_list = []
h_list = []
step_count = []

# Initializing counter for accepted steps
accepted_steps = 0

# Function to perform MCMC iterations
def perform_mcmc(dataframe, N_steps, Omega_M, Omega_L, h):
    global accepted_steps  # declare global variable
    # Initialize best chi-squared value
    chi2_total_best = float('inf')
    # Open file to save MCMC chain
    filename = "MC_Chain_SNIa_Week2_BR.txt"
    with open(filename, "w") as file:
        # Perform MCMC iterations
        for i in range(N_steps):
            # Calculate current chi-squared
            chi_squared_current = chi_squared(h, Omega_M, Omega_L, dataframe)
            # Append current chi-squared value to the list
            chi_squared_values.append(chi_squared_current)

            # Propose new parameters
            h_proposed, OmegaM_proposed, OmegaL_proposed = new_parameters(h, Omega_M, Omega_L)

            # Calculate new chi-squared
            chi_squared_proposed = chi_squared(h_proposed, OmegaM_proposed, OmegaL_proposed, dataframe)
            #saving all the steps in the lists
            Omega_M_list.append(OmegaM_proposed)
            Omega_L_list.append(OmegaL_proposed)
            h_list.append(h_proposed)
            step_count.append(i+1)
            # Accept or reject the proposal
            if chi_squared_proposed < chi_squared_current or np.random.uniform(0, 1) < np.exp((chi_squared_current - chi_squared_proposed) / 2):
                Omega_M = OmegaM_proposed
                Omega_L = OmegaL_proposed
                h = h_proposed
                accepted = True
                accepted_steps += 1  # Update accepted steps counter
            else:
                accepted = False
            # Save the accepted parameters to file
            file.write(f"{h} {Omega_M} {Omega_L} {accepted}\n")

            # Update best chi-squared if a better point is found
            if chi_squared_current < chi2_total_best:
                Omega_M_best = Omega_M
                Omega_L_best = Omega_L
                h_best = h
                chi2_total_best = chi_squared_current
                chi_squared_values.append(chi_squared_current)
            # Print current parameters
            print(f"Step {i+1}/{N_steps}: Current Chi^2 = {chi_squared_current}, Best Chi^2 = {chi2_total_best}")
            print(f"Current Parameters: Omega_M = {Omega_M}, Omega_L = {Omega_L}, h = {h}")

    return Omega_M_best, Omega_L_best, h_best, chi2_total_best

# Set initial parameter values
Omega_M = 0.2
Omega_L = 0.2
h = 0.2

# Call the MCMC function
Omega_M_best, Omega_L_best, h_best, chi2_total_best = perform_mcmc(dataframe, N_steps=5000, Omega_M=Omega_M, Omega_L=Omega_L, h=h)

print("Best parameters:")
print(f"Omega_M: {Omega_M_best}, Omega_L: {Omega_L_best}, h: {h_best}, Best Chi^2: {chi2_total_best}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Step 2502/5000: Current Chi^2 = 563.7449037141588, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1527890399858184, Omega_L = 0.6994996388637273, h = 0.5929683097313043
# Step 2503/5000: Current Chi^2 = 563.7449037141588, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1531292853326154, Omega_L = 0.6962233934092495, h = 0.5860746552904802
# Step 2504/5000: Current Chi^2 = 563.0713290233268, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1531292853326154, Omega_L = 0.6962233934092495, h = 0.5860746552904802
# Step 2505/5000: Current Chi^2 = 563.0713290233268, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1531292853326154, Omega_L = 0.6962233934092495, h = 0.5860746552904802
# Step 2506/5000: Current Chi^2 = 563.0713290233268, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1531292853326154, Omega_L = 0.6962233934092495, h = 0.5860746552904802
# Step 2507/5000: Current Chi^2 = 563.0713290233268, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1531292853326154, Omega_L = 0.6962233934092495, h = 0.5860746552904802
# Step 2508/5000: Current Chi^2 = 563.0713290233268, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1526860601125435, Omega_L = 0.6948622200200383, h = 0.5818639959070611
# Step 2509/5000: Current Chi^2 = 563.64639451014, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1526860601125435, Omega_L = 0.6948622200200383, h = 0.5818639959070611
# Step 2510/5000: Current Chi^2 = 563.64639451014, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1526860601125435, Omega_L = 0.6948622200200383, h = 0.5818639959070611
# Step 2511/5000: Current Chi^2 = 563.64639451014, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15141979647823156, Omega_L = 0.6975328644034163, h = 0.585568064116031
# Step 2512/5000: Current Chi^2 = 563.0894745360625, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15141979647823156, Omega_L = 0.6975328644034163, h = 0.585568064116031
# Step 2513/5000: Current Chi^2 = 563.0894745360625, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15141979647823156, Omega_L = 0.6975328644034163, h = 0.585568064116031
# Step 2514/5000: Current Chi^2 = 563.0894745360625, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15304615220978351, Omega_L = 0.6932468299409668, h = 0.5858540860593177
# Step 2515/5000: Current Chi^2 = 565.3558597800775, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15513815035097442, Omega_L = 0.6933324350506431, h = 0.5988265437783636
# Step 2516/5000: Current Chi^2 = 566.1773687555203, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15513815035097442, Omega_L = 0.6933324350506431, h = 0.5988265437783636
# Step 2517/5000: Current Chi^2 = 566.1773687555203, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15513815035097442, Omega_L = 0.6933324350506431, h = 0.5988265437783636
# Step 2518/5000: Current Chi^2 = 566.1773687555203, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15513815035097442, Omega_L = 0.6933324350506431, h = 0.5988265437783636
# Step 2519/5000: Current Chi^2 = 566.1773687555203, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15513815035097442, Omega_L = 0.6933324350506431, h = 0.5988265437783636
# Step 2520/5000: Current Chi^2 = 566.1773687555203, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15513815035097442, Omega_L = 0.6933324350506431, h = 0.5988265437783636
# Step 2521/5000: Current Chi^2 = 566.1773687555203, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15513815035097442, Omega_L = 0.6933324350506431, h = 0.5988265437783636
# Step 2522/5000: Current Chi^2 = 566.1773687555203, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15513815035097442, Omega_L = 0.6933324350506431, h = 0.5988265437783636
# Step 2523/5000: Current Chi^2 = 566.1773687555203, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15450652355102162, Omega_L = 0.6949254211943267, h = 0.5986196292590669
# Step 2524/5000: Current Chi^2 = 564.1018593151913, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15336883206815835, Omega_L = 0.6942782694388047, h = 0.5925326805443407
# Step 2525/5000: Current Chi^2 = 564.4887760002366, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15336883206815835, Omega_L = 0.6942782694388047, h = 0.5925326805443407
# Step 2526/5000: Current Chi^2 = 564.4887760002366, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15336883206815835, Omega_L = 0.6942782694388047, h = 0.5925326805443407
# Step 2527/5000: Current Chi^2 = 564.4887760002366, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15336883206815835, Omega_L = 0.6942782694388047, h = 0.5925326805443407
# Step 2528/5000: Current Chi^2 = 564.4887760002366, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15336883206815835, Omega_L = 0.6942782694388047, h = 0.5925326805443407
# Step 2529/5000: Current Chi^2 = 564.4887760002366, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15248215584707214, Omega_L = 0.6982308349677806, h = 0.585806853207679
# Step 2530/5000: Current Chi^2 = 563.4049021025928, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15381330517733235, Omega_L = 0.6979838432061869, h = 0.5920723934734964
# Step 2531/5000: Current Chi^2 = 562.9870751829724, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15381330517733235, Omega_L = 0.6979838432061869, h = 0.5920723934734964
# Step 2532/5000: Current Chi^2 = 562.9870751829724, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15706129619222217, Omega_L = 0.6947343284043183, h = 0.5947201102839171
# Step 2533/5000: Current Chi^2 = 563.9859499623714, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15706129619222217, Omega_L = 0.6947343284043183, h = 0.5947201102839171
# Step 2534/5000: Current Chi^2 = 563.9859499623714, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15706129619222217, Omega_L = 0.6947343284043183, h = 0.5947201102839171
# Step 2535/5000: Current Chi^2 = 563.9859499623714, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15586860727889734, Omega_L = 0.6968063487830777, h = 0.5960469405941119
# Step 2536/5000: Current Chi^2 = 562.8563042443436, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15586860727889734, Omega_L = 0.6968063487830777, h = 0.5960469405941119
# Step 2537/5000: Current Chi^2 = 562.8563042443436, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1565420112816965, Omega_L = 0.6969588025180113, h = 0.5994776500296684
# Step 2538/5000: Current Chi^2 = 562.811471996439, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1565420112816965, Omega_L = 0.6969588025180113, h = 0.5994776500296684
# Step 2539/5000: Current Chi^2 = 562.811471996439, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1573570698643962, Omega_L = 0.6968303467225382, h = 0.5999170852730732
# Step 2540/5000: Current Chi^2 = 562.8406864704617, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1573570698643962, Omega_L = 0.6968303467225382, h = 0.5999170852730732
# Step 2541/5000: Current Chi^2 = 562.8406864704617, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1573570698643962, Omega_L = 0.6968303467225382, h = 0.5999170852730732
# Step 2542/5000: Current Chi^2 = 562.8406864704617, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1573570698643962, Omega_L = 0.6968303467225382, h = 0.5999170852730732
# Step 2543/5000: Current Chi^2 = 562.8406864704617, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1573570698643962, Omega_L = 0.6968303467225382, h = 0.5999170852730732
# Step 2544/5000: Current Chi^2 = 562.8406864704617, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15971863806275746, Omega_L = 0.7024773143499538, h = 0.6048769433108786
# Step 2545/5000: Current Chi^2 = 566.7969285053454, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15971863806275746, Omega_L = 0.7024773143499538, h = 0.6048769433108786
# Step 2546/5000: Current Chi^2 = 566.7969285053454, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16020825332678895, Omega_L = 0.7013952478588728, h = 0.6142751246836571
# Step 2547/5000: Current Chi^2 = 564.235197904073, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16020825332678895, Omega_L = 0.7013952478588728, h = 0.6142751246836571
# Step 2548/5000: Current Chi^2 = 564.235197904073, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16020825332678895, Omega_L = 0.7013952478588728, h = 0.6142751246836571
# Step 2549/5000: Current Chi^2 = 564.235197904073, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16020825332678895, Omega_L = 0.7013952478588728, h = 0.6142751246836571
# Step 2550/5000: Current Chi^2 = 564.235197904073, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16020825332678895, Omega_L = 0.7013952478588728, h = 0.6142751246836571
# Step 2551/5000: Current Chi^2 = 564.235197904073, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16020825332678895, Omega_L = 0.7013952478588728, h = 0.6142751246836571
# Step 2552/5000: Current Chi^2 = 564.235197904073, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1598082231844031, Omega_L = 0.6997422869765698, h = 0.6059872657036617
# Step 2553/5000: Current Chi^2 = 563.3324451064753, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16082560697170337, Omega_L = 0.6977260375852139, h = 0.5889032369694049
# Step 2554/5000: Current Chi^2 = 563.3689163257842, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1618052211573891, Omega_L = 0.6967369525038615, h = 0.5926641197413973
# Step 2555/5000: Current Chi^2 = 563.0051313067476, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1618052211573891, Omega_L = 0.6967369525038615, h = 0.5926641197413973
# Step 2556/5000: Current Chi^2 = 563.0051313067476, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16100489778729296, Omega_L = 0.6958646480199276, h = 0.5978828451085016
# Step 2557/5000: Current Chi^2 = 563.1741182492862, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16100489778729296, Omega_L = 0.6958646480199276, h = 0.5978828451085016
# Step 2558/5000: Current Chi^2 = 563.1741182492862, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16100489778729296, Omega_L = 0.6958646480199276, h = 0.5978828451085016
# Step 2559/5000: Current Chi^2 = 563.1741182492862, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16100489778729296, Omega_L = 0.6958646480199276, h = 0.5978828451085016
# Step 2560/5000: Current Chi^2 = 563.1741182492862, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1614001212052684, Omega_L = 0.6964559526583095, h = 0.6030486554168952
# Step 2561/5000: Current Chi^2 = 562.9581881142828, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16068483364636768, Omega_L = 0.6991875952916968, h = 0.6035599509252725
# Step 2562/5000: Current Chi^2 = 563.1628658644344, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16068483364636768, Omega_L = 0.6991875952916968, h = 0.6035599509252725
# Step 2563/5000: Current Chi^2 = 563.1628658644344, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16068483364636768, Omega_L = 0.6991875952916968, h = 0.6035599509252725
# Step 2564/5000: Current Chi^2 = 563.1628658644344, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16068483364636768, Omega_L = 0.6991875952916968, h = 0.6035599509252725
# Step 2565/5000: Current Chi^2 = 563.1628658644344, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16068483364636768, Omega_L = 0.6991875952916968, h = 0.6035599509252725
# Step 2566/5000: Current Chi^2 = 563.1628658644344, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.16068483364636768, Omega_L = 0.6991875952916968, h = 0.6035599509252725
# Step 2567/5000: Current Chi^2 = 563.1628658644344, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1588501017269232, Omega_L = 0.6971261319564697, h = 0.6094771580301457
# Step 2568/5000: Current Chi^2 = 562.8426915332238, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1588501017269232, Omega_L = 0.6971261319564697, h = 0.6094771580301457
# Step 2569/5000: Current Chi^2 = 562.8426915332238, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1588501017269232, Omega_L = 0.6971261319564697, h = 0.6094771580301457
# Step 2570/5000: Current Chi^2 = 562.8426915332238, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15722412799468763, Omega_L = 0.6984148213958109, h = 0.6167719231906337
# Step 2571/5000: Current Chi^2 = 562.6786575802694, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15722412799468763, Omega_L = 0.6984148213958109, h = 0.6167719231906337
# Step 2572/5000: Current Chi^2 = 562.6786575802694, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15722412799468763, Omega_L = 0.6984148213958109, h = 0.6167719231906337
# Step 2573/5000: Current Chi^2 = 562.6786575802694, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15722412799468763, Omega_L = 0.6984148213958109, h = 0.6167719231906337
# Step 2574/5000: Current Chi^2 = 562.6786575802694, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15635063244501282, Omega_L = 0.6949004997887569, h = 0.6022303657959228
# Step 2575/5000: Current Chi^2 = 564.2615535281697, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15635063244501282, Omega_L = 0.6949004997887569, h = 0.6022303657959228
# Step 2576/5000: Current Chi^2 = 564.2615535281697, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15635063244501282, Omega_L = 0.6949004997887569, h = 0.6022303657959228
# Step 2577/5000: Current Chi^2 = 564.2615535281697, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15635063244501282, Omega_L = 0.6949004997887569, h = 0.6022303657959228
# Step 2578/5000: Current Chi^2 = 564.2615535281697, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15635063244501282, Omega_L = 0.6949004997887569, h = 0.6022303657959228
# Step 2579/5000: Current Chi^2 = 564.2615535281697, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15635063244501282, Omega_L = 0.6949004997887569, h = 0.6022303657959228
# Step 2580/5000: Current Chi^2 = 564.2615535281697, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1555323625148157, Omega_L = 0.7011528760694676, h = 0.6107891857175268
# Step 2581/5000: Current Chi^2 = 564.012064955673, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1555323625148157, Omega_L = 0.7011528760694676, h = 0.6107891857175268
# Step 2582/5000: Current Chi^2 = 564.012064955673, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1555323625148157, Omega_L = 0.7011528760694676, h = 0.6107891857175268
# Step 2583/5000: Current Chi^2 = 564.012064955673, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1555323625148157, Omega_L = 0.7011528760694676, h = 0.6107891857175268
# Step 2584/5000: Current Chi^2 = 564.012064955673, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15460430110928045, Omega_L = 0.6981651640587622, h = 0.6208539102691676
# Step 2585/5000: Current Chi^2 = 562.9639681724452, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1579429533154034, Omega_L = 0.7003979380066151, h = 0.626396843643184
# Step 2586/5000: Current Chi^2 = 562.9254298779053, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1579429533154034, Omega_L = 0.7003979380066151, h = 0.626396843643184
# Step 2587/5000: Current Chi^2 = 562.9254298779053, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1579429533154034, Omega_L = 0.7003979380066151, h = 0.626396843643184
# Step 2588/5000: Current Chi^2 = 562.9254298779053, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1579429533154034, Omega_L = 0.7003979380066151, h = 0.626396843643184
# Step 2589/5000: Current Chi^2 = 562.9254298779053, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1579429533154034, Omega_L = 0.7003979380066151, h = 0.626396843643184
# Step 2590/5000: Current Chi^2 = 562.9254298779053, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1579429533154034, Omega_L = 0.7003979380066151, h = 0.626396843643184
# Step 2591/5000: Current Chi^2 = 562.9254298779053, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1579429533154034, Omega_L = 0.7003979380066151, h = 0.626396843643184
# Step 2592/5000: Current Chi^2 = 562.9254298779053, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15618120542531091, Omega_L = 0.7002580843919207, h = 0.6259705796713642
# Step 2593/5000: Current Chi^2 = 562.8994523269059, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15618120542531091, Omega_L = 0.7002580843919207, h = 0.6259705796713642
# Step 2594/5000: Current Chi^2 = 562.8994523269059, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15562246842610944, Omega_L = 0.6990501295929745, h = 0.6303471340217099
# Step 2595/5000: Current Chi^2 = 563.0685539268133, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15562246842610944, Omega_L = 0.6990501295929745, h = 0.6303471340217099
# Step 2596/5000: Current Chi^2 = 563.0685539268133, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15562246842610944, Omega_L = 0.6990501295929745, h = 0.6303471340217099
# Step 2597/5000: Current Chi^2 = 563.0685539268133, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15626203533702238, Omega_L = 0.6998660934221824, h = 0.6219901055395128
# Step 2598/5000: Current Chi^2 = 562.7993853609188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15626203533702238, Omega_L = 0.6998660934221824, h = 0.6219901055395128
# Step 2599/5000: Current Chi^2 = 562.7993853609188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15626203533702238, Omega_L = 0.6998660934221824, h = 0.6219901055395128
# Step 2600/5000: Current Chi^2 = 562.7993853609188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2601/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2602/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2603/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2604/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2605/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2606/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2607/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2608/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1542981460604677, Omega_L = 0.7011548981950665, h = 0.6302072710874848
# Step 2609/5000: Current Chi^2 = 563.2398028049108, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15438394446047546, Omega_L = 0.7001469882276938, h = 0.6336351609860429
# Step 2610/5000: Current Chi^2 = 563.0877724057455, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15438394446047546, Omega_L = 0.7001469882276938, h = 0.6336351609860429
# Step 2611/5000: Current Chi^2 = 563.0877724057455, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15438394446047546, Omega_L = 0.7001469882276938, h = 0.6336351609860429
# Step 2612/5000: Current Chi^2 = 563.0877724057455, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15389758882185997, Omega_L = 0.6992799793077715, h = 0.6433953910280783
# Step 2613/5000: Current Chi^2 = 564.0800807449317, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15389758882185997, Omega_L = 0.6992799793077715, h = 0.6433953910280783
# Step 2614/5000: Current Chi^2 = 564.0800807449317, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15389758882185997, Omega_L = 0.6992799793077715, h = 0.6433953910280783
# Step 2615/5000: Current Chi^2 = 564.0800807449317, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.15199632784346084, Omega_L = 0.7021460645825232, h = 0.6439573614128329
# Step 2616/5000: Current Chi^2 = 563.8732636246821, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14985901810915267, Omega_L = 0.6988305665863112, h = 0.6356729500892142
# Step 2617/5000: Current Chi^2 = 563.9736136972288, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14880045155947488, Omega_L = 0.6974123027434941, h = 0.6319464108178812
# Step 2618/5000: Current Chi^2 = 564.9350293994355, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14880045155947488, Omega_L = 0.6974123027434941, h = 0.6319464108178812
# Step 2619/5000: Current Chi^2 = 564.9350293994355, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14756102567947244, Omega_L = 0.6983510503539442, h = 0.6300214167697631
# Step 2620/5000: Current Chi^2 = 563.9669783239593, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14756102567947244, Omega_L = 0.6983510503539442, h = 0.6300214167697631
# Step 2621/5000: Current Chi^2 = 563.9669783239593, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14756102567947244, Omega_L = 0.6983510503539442, h = 0.6300214167697631
# Step 2622/5000: Current Chi^2 = 563.9669783239593, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14756102567947244, Omega_L = 0.6983510503539442, h = 0.6300214167697631
# Step 2623/5000: Current Chi^2 = 563.9669783239593, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14756102567947244, Omega_L = 0.6983510503539442, h = 0.6300214167697631
# Step 2624/5000: Current Chi^2 = 563.9669783239593, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14756102567947244, Omega_L = 0.6983510503539442, h = 0.6300214167697631
# Step 2625/5000: Current Chi^2 = 563.9669783239593, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14756102567947244, Omega_L = 0.6983510503539442, h = 0.6300214167697631
# Step 2626/5000: Current Chi^2 = 563.9669783239593, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14969543014901246, Omega_L = 0.7009778039205622, h = 0.6286628214275359
# Step 2627/5000: Current Chi^2 = 563.2390141187944, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14924044496287192, Omega_L = 0.6991410949883478, h = 0.6302560861551297
# Step 2628/5000: Current Chi^2 = 563.4030793684095, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14924044496287192, Omega_L = 0.6991410949883478, h = 0.6302560861551297
# Step 2629/5000: Current Chi^2 = 563.4030793684095, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14924044496287192, Omega_L = 0.6991410949883478, h = 0.6302560861551297
# Step 2630/5000: Current Chi^2 = 563.4030793684095, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14924044496287192, Omega_L = 0.6991410949883478, h = 0.6302560861551297
# Step 2631/5000: Current Chi^2 = 563.4030793684095, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14787132016963087, Omega_L = 0.7016070155706136, h = 0.632606732176693
# Step 2632/5000: Current Chi^2 = 563.5603071267985, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14787132016963087, Omega_L = 0.7016070155706136, h = 0.632606732176693
# Step 2633/5000: Current Chi^2 = 563.5603071267985, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14787132016963087, Omega_L = 0.7016070155706136, h = 0.632606732176693
# Step 2634/5000: Current Chi^2 = 563.5603071267985, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14787132016963087, Omega_L = 0.7016070155706136, h = 0.632606732176693
# Step 2635/5000: Current Chi^2 = 563.5603071267985, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14787132016963087, Omega_L = 0.7016070155706136, h = 0.632606732176693
# Step 2636/5000: Current Chi^2 = 563.5603071267985, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14787132016963087, Omega_L = 0.7016070155706136, h = 0.632606732176693
# Step 2637/5000: Current Chi^2 = 563.5603071267985, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.146249278163765, Omega_L = 0.7014955183466611, h = 0.6272324706117778
# Step 2638/5000: Current Chi^2 = 563.5040876070188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.146249278163765, Omega_L = 0.7014955183466611, h = 0.6272324706117778
# Step 2639/5000: Current Chi^2 = 563.5040876070188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.146249278163765, Omega_L = 0.7014955183466611, h = 0.6272324706117778
# Step 2640/5000: Current Chi^2 = 563.5040876070188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.146249278163765, Omega_L = 0.7014955183466611, h = 0.6272324706117778
# Step 2641/5000: Current Chi^2 = 563.5040876070188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.146249278163765, Omega_L = 0.7014955183466611, h = 0.6272324706117778
# Step 2642/5000: Current Chi^2 = 563.5040876070188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.146249278163765, Omega_L = 0.7014955183466611, h = 0.6272324706117778
# Step 2643/5000: Current Chi^2 = 563.5040876070188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.146249278163765, Omega_L = 0.7014955183466611, h = 0.6272324706117778
# Step 2644/5000: Current Chi^2 = 563.5040876070188, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1445633620580413, Omega_L = 0.702786153255583, h = 0.6341846137122834
# Step 2645/5000: Current Chi^2 = 564.3076000795218, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1445633620580413, Omega_L = 0.702786153255583, h = 0.6341846137122834
# Step 2646/5000: Current Chi^2 = 564.3076000795218, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14459813641311275, Omega_L = 0.7011001889561543, h = 0.6446850951081208
# Step 2647/5000: Current Chi^2 = 564.2486909878609, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14459813641311275, Omega_L = 0.7011001889561543, h = 0.6446850951081208
# Step 2648/5000: Current Chi^2 = 564.2486909878609, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14459813641311275, Omega_L = 0.7011001889561543, h = 0.6446850951081208
# Step 2649/5000: Current Chi^2 = 564.2486909878609, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14459813641311275, Omega_L = 0.7011001889561543, h = 0.6446850951081208
# Step 2650/5000: Current Chi^2 = 564.2486909878609, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2651/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2652/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2653/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2654/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2655/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2656/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2657/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2658/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2659/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2660/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14545458846326512, Omega_L = 0.7029191648747247, h = 0.6512389476365882
# Step 2661/5000: Current Chi^2 = 564.7567093541836, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14536456139000728, Omega_L = 0.7054761351207609, h = 0.6591989360482475
# Step 2662/5000: Current Chi^2 = 566.7582483020057, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14448083854307783, Omega_L = 0.7004363447469134, h = 0.6618000174435581
# Step 2663/5000: Current Chi^2 = 566.7633550046509, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14448083854307783, Omega_L = 0.7004363447469134, h = 0.6618000174435581
# Step 2664/5000: Current Chi^2 = 566.7633550046509, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14448083854307783, Omega_L = 0.7004363447469134, h = 0.6618000174435581
# Step 2665/5000: Current Chi^2 = 566.7633550046509, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14343483922864392, Omega_L = 0.7009860696953826, h = 0.6647418902701909
# Step 2666/5000: Current Chi^2 = 566.9319043558417, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14343483922864392, Omega_L = 0.7009860696953826, h = 0.6647418902701909
# Step 2667/5000: Current Chi^2 = 566.9319043558417, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14343483922864392, Omega_L = 0.7009860696953826, h = 0.6647418902701909
# Step 2668/5000: Current Chi^2 = 566.9319043558417, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1425733412811903, Omega_L = 0.7014932332861915, h = 0.6556567330003475
# Step 2669/5000: Current Chi^2 = 565.4369223011117, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1425350987945738, Omega_L = 0.6990590105663923, h = 0.6609439058036125
# Step 2670/5000: Current Chi^2 = 568.5641241033688, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1428511302678517, Omega_L = 0.7001549139668573, h = 0.6632265957420972
# Step 2671/5000: Current Chi^2 = 567.5577096632657, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1428511302678517, Omega_L = 0.7001549139668573, h = 0.6632265957420972
# Step 2672/5000: Current Chi^2 = 567.5577096632657, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.143009114399328, Omega_L = 0.6995244691733835, h = 0.6653084894209084
# Step 2673/5000: Current Chi^2 = 568.7338885663555, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14291910285137027, Omega_L = 0.7058505058490401, h = 0.6535111469358029
# Step 2674/5000: Current Chi^2 = 567.2554167784615, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14291910285137027, Omega_L = 0.7058505058490401, h = 0.6535111469358029
# Step 2675/5000: Current Chi^2 = 567.2554167784615, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1417185748960839, Omega_L = 0.7006923663001458, h = 0.6564055112244946
# Step 2676/5000: Current Chi^2 = 566.0933411202471, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1417185748960839, Omega_L = 0.7006923663001458, h = 0.6564055112244946
# Step 2677/5000: Current Chi^2 = 566.0933411202471, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14104445003258195, Omega_L = 0.7007111314908517, h = 0.6553677077148877
# Step 2678/5000: Current Chi^2 = 566.0175615285948, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14104445003258195, Omega_L = 0.7007111314908517, h = 0.6553677077148877
# Step 2679/5000: Current Chi^2 = 566.0175615285948, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14104445003258195, Omega_L = 0.7007111314908517, h = 0.6553677077148877
# Step 2680/5000: Current Chi^2 = 566.0175615285948, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14104445003258195, Omega_L = 0.7007111314908517, h = 0.6553677077148877
# Step 2681/5000: Current Chi^2 = 566.0175615285948, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14104445003258195, Omega_L = 0.7007111314908517, h = 0.6553677077148877
# Step 2682/5000: Current Chi^2 = 566.0175615285948, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14104445003258195, Omega_L = 0.7007111314908517, h = 0.6553677077148877
# Step 2683/5000: Current Chi^2 = 566.0175615285948, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14104445003258195, Omega_L = 0.7007111314908517, h = 0.6553677077148877
# Step 2684/5000: Current Chi^2 = 566.0175615285948, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14002794140724448, Omega_L = 0.703802579698916, h = 0.6544035854707486
# Step 2685/5000: Current Chi^2 = 565.617195138288, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14002794140724448, Omega_L = 0.703802579698916, h = 0.6544035854707486
# Step 2686/5000: Current Chi^2 = 565.617195138288, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14002794140724448, Omega_L = 0.703802579698916, h = 0.6544035854707486
# Step 2687/5000: Current Chi^2 = 565.617195138288, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1390957408506065, Omega_L = 0.7054959232760251, h = 0.64633999447478
# Step 2688/5000: Current Chi^2 = 566.9573266050656, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1390957408506065, Omega_L = 0.7054959232760251, h = 0.64633999447478
# Step 2689/5000: Current Chi^2 = 566.9573266050656, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1390957408506065, Omega_L = 0.7054959232760251, h = 0.64633999447478
# Step 2690/5000: Current Chi^2 = 566.9573266050656, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1390957408506065, Omega_L = 0.7054959232760251, h = 0.64633999447478
# Step 2691/5000: Current Chi^2 = 566.9573266050656, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1390957408506065, Omega_L = 0.7054959232760251, h = 0.64633999447478
# Step 2692/5000: Current Chi^2 = 566.9573266050656, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13715108026831893, Omega_L = 0.7048857293848677, h = 0.6485580427519142
# Step 2693/5000: Current Chi^2 = 566.3123035097708, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13715108026831893, Omega_L = 0.7048857293848677, h = 0.6485580427519142
# Step 2694/5000: Current Chi^2 = 566.3123035097708, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13715108026831893, Omega_L = 0.7048857293848677, h = 0.6485580427519142
# Step 2695/5000: Current Chi^2 = 566.3123035097708, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13715108026831893, Omega_L = 0.7048857293848677, h = 0.6485580427519142
# Step 2696/5000: Current Chi^2 = 566.3123035097708, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13699445980689365, Omega_L = 0.7015521661745647, h = 0.6514418146555995
# Step 2697/5000: Current Chi^2 = 565.5421529179791, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13699445980689365, Omega_L = 0.7015521661745647, h = 0.6514418146555995
# Step 2698/5000: Current Chi^2 = 565.5421529179791, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13699445980689365, Omega_L = 0.7015521661745647, h = 0.6514418146555995
# Step 2699/5000: Current Chi^2 = 565.5421529179791, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13699445980689365, Omega_L = 0.7015521661745647, h = 0.6514418146555995
# Step 2700/5000: Current Chi^2 = 565.5421529179791, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13699445980689365, Omega_L = 0.7015521661745647, h = 0.6514418146555995
# Step 2701/5000: Current Chi^2 = 565.5421529179791, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13775272461959498, Omega_L = 0.7062745557045451, h = 0.6700266842048194
# Step 2702/5000: Current Chi^2 = 568.2657071311867, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13775272461959498, Omega_L = 0.7062745557045451, h = 0.6700266842048194
# Step 2703/5000: Current Chi^2 = 568.2657071311867, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13775272461959498, Omega_L = 0.7062745557045451, h = 0.6700266842048194
# Step 2704/5000: Current Chi^2 = 568.2657071311867, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1377338722348267, Omega_L = 0.7041955574584914, h = 0.6774464308578098
# Step 2705/5000: Current Chi^2 = 568.2307069366244, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1377338722348267, Omega_L = 0.7041955574584914, h = 0.6774464308578098
# Step 2706/5000: Current Chi^2 = 568.2307069366244, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1377338722348267, Omega_L = 0.7041955574584914, h = 0.6774464308578098
# Step 2707/5000: Current Chi^2 = 568.2307069366244, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1377338722348267, Omega_L = 0.7041955574584914, h = 0.6774464308578098
# Step 2708/5000: Current Chi^2 = 568.2307069366244, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1377338722348267, Omega_L = 0.7041955574584914, h = 0.6774464308578098
# Step 2709/5000: Current Chi^2 = 568.2307069366244, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13624189202321232, Omega_L = 0.6995302023941703, h = 0.6667900118099397
# Step 2710/5000: Current Chi^2 = 570.3937613534725, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13815456451317332, Omega_L = 0.7018307645908076, h = 0.660102716421524
# Step 2711/5000: Current Chi^2 = 566.4098238376378, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13815456451317332, Omega_L = 0.7018307645908076, h = 0.660102716421524
# Step 2712/5000: Current Chi^2 = 566.4098238376378, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13815456451317332, Omega_L = 0.7018307645908076, h = 0.660102716421524
# Step 2713/5000: Current Chi^2 = 566.4098238376378, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13815456451317332, Omega_L = 0.7018307645908076, h = 0.660102716421524
# Step 2714/5000: Current Chi^2 = 566.4098238376378, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13815456451317332, Omega_L = 0.7018307645908076, h = 0.660102716421524
# Step 2715/5000: Current Chi^2 = 566.4098238376378, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13815456451317332, Omega_L = 0.7018307645908076, h = 0.660102716421524
# Step 2716/5000: Current Chi^2 = 566.4098238376378, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13815456451317332, Omega_L = 0.7018307645908076, h = 0.660102716421524
# Step 2717/5000: Current Chi^2 = 566.4098238376378, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13666936607867877, Omega_L = 0.7051658294706744, h = 0.6557776395747643
# Step 2718/5000: Current Chi^2 = 566.7544769042544, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13666936607867877, Omega_L = 0.7051658294706744, h = 0.6557776395747643
# Step 2719/5000: Current Chi^2 = 566.7544769042544, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13724917993999775, Omega_L = 0.7040306916323806, h = 0.6620729110427371
# Step 2720/5000: Current Chi^2 = 566.4822265082512, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13724917993999775, Omega_L = 0.7040306916323806, h = 0.6620729110427371
# Step 2721/5000: Current Chi^2 = 566.4822265082512, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13675056759273177, Omega_L = 0.7016302689201569, h = 0.6619649058189624
# Step 2722/5000: Current Chi^2 = 566.999413894421, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13675056759273177, Omega_L = 0.7016302689201569, h = 0.6619649058189624
# Step 2723/5000: Current Chi^2 = 566.999413894421, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13675056759273177, Omega_L = 0.7016302689201569, h = 0.6619649058189624
# Step 2724/5000: Current Chi^2 = 566.999413894421, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13590937331594838, Omega_L = 0.708612921507724, h = 0.6701646453091403
# Step 2725/5000: Current Chi^2 = 571.3216539555375, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13787343792904838, Omega_L = 0.6987869664453487, h = 0.6633249878407421
# Step 2726/5000: Current Chi^2 = 570.4465258392349, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13787343792904838, Omega_L = 0.6987869664453487, h = 0.6633249878407421
# Step 2727/5000: Current Chi^2 = 570.4465258392349, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13787343792904838, Omega_L = 0.6987869664453487, h = 0.6633249878407421
# Step 2728/5000: Current Chi^2 = 570.4465258392349, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13787343792904838, Omega_L = 0.6987869664453487, h = 0.6633249878407421
# Step 2729/5000: Current Chi^2 = 570.4465258392349, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13787343792904838, Omega_L = 0.6987869664453487, h = 0.6633249878407421
# Step 2730/5000: Current Chi^2 = 570.4465258392349, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13787343792904838, Omega_L = 0.6987869664453487, h = 0.6633249878407421
# Step 2731/5000: Current Chi^2 = 570.4465258392349, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13787343792904838, Omega_L = 0.6987869664453487, h = 0.6633249878407421
# Step 2732/5000: Current Chi^2 = 570.4465258392349, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.13771234439371113, Omega_L = 0.7000462583248735, h = 0.6524613724705494
# Step 2733/5000: Current Chi^2 = 566.5837766640639, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1412748454575343, Omega_L = 0.7064176925993203, h = 0.6453550238521245
# Step 2734/5000: Current Chi^2 = 568.3726078285431, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1422501130197833, Omega_L = 0.6993495361406719, h = 0.6411931316292386
# Step 2735/5000: Current Chi^2 = 564.9679073680686, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14274329192357516, Omega_L = 0.6988823864505517, h = 0.6303933843638888
# Step 2736/5000: Current Chi^2 = 564.0519554411012, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14274329192357516, Omega_L = 0.6988823864505517, h = 0.6303933843638888
# Step 2737/5000: Current Chi^2 = 564.0519554411012, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14274329192357516, Omega_L = 0.6988823864505517, h = 0.6303933843638888
# Step 2738/5000: Current Chi^2 = 564.0519554411012, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14274329192357516, Omega_L = 0.6988823864505517, h = 0.6303933843638888
# Step 2739/5000: Current Chi^2 = 564.0519554411012, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14361334753976954, Omega_L = 0.6997530712311202, h = 0.6336752728379185
# Step 2740/5000: Current Chi^2 = 563.8162390134127, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1423702210946864, Omega_L = 0.7019067597786304, h = 0.6350078179867731
# Step 2741/5000: Current Chi^2 = 563.9031283002896, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1423702210946864, Omega_L = 0.7019067597786304, h = 0.6350078179867731
# Step 2742/5000: Current Chi^2 = 563.9031283002896, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1423702210946864, Omega_L = 0.7019067597786304, h = 0.6350078179867731
# Step 2743/5000: Current Chi^2 = 563.9031283002896, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1423702210946864, Omega_L = 0.7019067597786304, h = 0.6350078179867731
# Step 2744/5000: Current Chi^2 = 563.9031283002896, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.1423702210946864, Omega_L = 0.7019067597786304, h = 0.6350078179867731
# Step 2745/5000: Current Chi^2 = 563.9031283002896, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14446920225076093, Omega_L = 0.6973745604013503, h = 0.6272440670633056
# Step 2746/5000: Current Chi^2 = 564.8556798872579, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14485221981039756, Omega_L = 0.6999438421356693, h = 0.6126013230906885
# Step 2747/5000: Current Chi^2 = 562.9361814559448, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14485221981039756, Omega_L = 0.6999438421356693, h = 0.6126013230906885
# Step 2748/5000: Current Chi^2 = 562.9361814559448, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2749/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2750/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2751/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2752/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2753/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2754/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2755/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2756/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2757/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14392641094379088, Omega_L = 0.6996306092453508, h = 0.6100157125046869
# Step 2758/5000: Current Chi^2 = 562.8704403087419, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14420569578086537, Omega_L = 0.6963645548777654, h = 0.6132815359152569
# Step 2759/5000: Current Chi^2 = 564.428530744943, Best Chi^2 = 562.5803417274536
# Current Parameters: Omega_M = 0.14754478193389498, Omega_L = 0.7029308542090289, h = 0.6152585662357305
# Step 2760/5000: Current Chi^2 = 565.3742852899101, Best Chi^2 = 562.5803417274536
# ...
# Current Parameters: Omega_M = 0.13183943266735623, Omega_L = 0.7035477663354395, h = 0.6068183704282492
# Step 4916/5000: Current Chi^2 = 566.1758422780048, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13183943266735623, Omega_L = 0.7035477663354395, h = 0.6068183704282492
# Step 4917/5000: Current Chi^2 = 566.1758422780048, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13183943266735623, Omega_L = 0.7035477663354395, h = 0.6068183704282492
# Step 4918/5000: Current Chi^2 = 566.1758422780048, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13183943266735623, Omega_L = 0.7035477663354395, h = 0.6068183704282492
# Step 4919/5000: Current Chi^2 = 566.1758422780048, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13476016683686046, Omega_L = 0.6994558375910871, h = 0.6006147775127173
# Step 4920/5000: Current Chi^2 = 562.9304929515864, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13476016683686046, Omega_L = 0.6994558375910871, h = 0.6006147775127173
# Step 4921/5000: Current Chi^2 = 562.9304929515864, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13476016683686046, Omega_L = 0.6994558375910871, h = 0.6006147775127173
# Step 4922/5000: Current Chi^2 = 562.9304929515864, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1365615963935193, Omega_L = 0.6975661392701659, h = 0.5984466666161339
# Step 4923/5000: Current Chi^2 = 562.9949658790448, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13653908908750378, Omega_L = 0.7036386474962811, h = 0.5940835504636709
# Step 4924/5000: Current Chi^2 = 568.1881387341523, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13653908908750378, Omega_L = 0.7036386474962811, h = 0.5940835504636709
# Step 4925/5000: Current Chi^2 = 568.1881387341523, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13653908908750378, Omega_L = 0.7036386474962811, h = 0.5940835504636709
# Step 4926/5000: Current Chi^2 = 568.1881387341523, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13761114686898937, Omega_L = 0.6975117555424674, h = 0.6012769417454467
# Step 4927/5000: Current Chi^2 = 563.0909201868178, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13761114686898937, Omega_L = 0.6975117555424674, h = 0.6012769417454467
# Step 4928/5000: Current Chi^2 = 563.0909201868178, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13761114686898937, Omega_L = 0.6975117555424674, h = 0.6012769417454467
# Step 4929/5000: Current Chi^2 = 563.0909201868178, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13761114686898937, Omega_L = 0.6975117555424674, h = 0.6012769417454467
# Step 4930/5000: Current Chi^2 = 563.0909201868178, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13761114686898937, Omega_L = 0.6975117555424674, h = 0.6012769417454467
# Step 4931/5000: Current Chi^2 = 563.0909201868178, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13528867487079188, Omega_L = 0.7008738981912265, h = 0.6073896816737663
# Step 4932/5000: Current Chi^2 = 563.426859125246, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13528867487079188, Omega_L = 0.7008738981912265, h = 0.6073896816737663
# Step 4933/5000: Current Chi^2 = 563.426859125246, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13528867487079188, Omega_L = 0.7008738981912265, h = 0.6073896816737663
# Step 4934/5000: Current Chi^2 = 563.426859125246, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13528867487079188, Omega_L = 0.7008738981912265, h = 0.6073896816737663
# Step 4935/5000: Current Chi^2 = 563.426859125246, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13528867487079188, Omega_L = 0.7008738981912265, h = 0.6073896816737663
# Step 4936/5000: Current Chi^2 = 563.426859125246, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13652535253377207, Omega_L = 0.7030694546048275, h = 0.6143258045030481
# Step 4937/5000: Current Chi^2 = 565.159440227254, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4938/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4939/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4940/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4941/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4942/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4943/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4944/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4945/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4946/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4947/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13663326664677525, Omega_L = 0.6982510178699362, h = 0.6032159079066933
# Step 4948/5000: Current Chi^2 = 562.9422469079141, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13660403475981261, Omega_L = 0.6999089311927897, h = 0.6049446458056973
# Step 4949/5000: Current Chi^2 = 563.0215133249774, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.13907939400010122, Omega_L = 0.7011820430291025, h = 0.6126319202551063
# Step 4950/5000: Current Chi^2 = 563.5169554337623, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1411199835862043, Omega_L = 0.7010443912036062, h = 0.6120199412735317
# Step 4951/5000: Current Chi^2 = 563.4553779592381, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4952/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4953/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4954/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4955/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4956/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4957/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4958/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4959/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4960/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4961/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4962/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4963/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4964/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4965/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4966/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4967/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.141244492174178, Omega_L = 0.6989019750471922, h = 0.6096193637952698
# Step 4968/5000: Current Chi^2 = 562.8687084071538, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14178216741221591, Omega_L = 0.6961085467354203, h = 0.6139398329127221
# Step 4969/5000: Current Chi^2 = 565.0239711087128, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14178216741221591, Omega_L = 0.6961085467354203, h = 0.6139398329127221
# Step 4970/5000: Current Chi^2 = 565.0239711087128, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14178216741221591, Omega_L = 0.6961085467354203, h = 0.6139398329127221
# Step 4971/5000: Current Chi^2 = 565.0239711087128, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1438064813729808, Omega_L = 0.7003549819203271, h = 0.6147184346515693
# Step 4972/5000: Current Chi^2 = 563.0690128519855, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1438064813729808, Omega_L = 0.7003549819203271, h = 0.6147184346515693
# Step 4973/5000: Current Chi^2 = 563.0690128519855, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14503721653209367, Omega_L = 0.7020034587530259, h = 0.6122611089976399
# Step 4974/5000: Current Chi^2 = 564.3493962053257, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14503721653209367, Omega_L = 0.7020034587530259, h = 0.6122611089976399
# Step 4975/5000: Current Chi^2 = 564.3493962053257, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14503721653209367, Omega_L = 0.7020034587530259, h = 0.6122611089976399
# Step 4976/5000: Current Chi^2 = 564.3493962053257, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1423127533504367, Omega_L = 0.7008040044916279, h = 0.6219745444501797
# Step 4977/5000: Current Chi^2 = 563.2713890433413, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1423127533504367, Omega_L = 0.7008040044916279, h = 0.6219745444501797
# Step 4978/5000: Current Chi^2 = 563.2713890433413, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1423127533504367, Omega_L = 0.7008040044916279, h = 0.6219745444501797
# Step 4979/5000: Current Chi^2 = 563.2713890433413, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1423127533504367, Omega_L = 0.7008040044916279, h = 0.6219745444501797
# Step 4980/5000: Current Chi^2 = 563.2713890433413, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1423127533504367, Omega_L = 0.7008040044916279, h = 0.6219745444501797
# Step 4981/5000: Current Chi^2 = 563.2713890433413, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1423127533504367, Omega_L = 0.7008040044916279, h = 0.6219745444501797
# Step 4982/5000: Current Chi^2 = 563.2713890433413, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14319466667561492, Omega_L = 0.7002895114395841, h = 0.6264166850490461
# Step 4983/5000: Current Chi^2 = 563.2868538919364, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14319466667561492, Omega_L = 0.7002895114395841, h = 0.6264166850490461
# Step 4984/5000: Current Chi^2 = 563.2868538919364, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1427835518151474, Omega_L = 0.7004724253456369, h = 0.6313673478485594
# Step 4985/5000: Current Chi^2 = 563.5405735664278, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1427835518151474, Omega_L = 0.7004724253456369, h = 0.6313673478485594
# Step 4986/5000: Current Chi^2 = 563.5405735664278, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1427835518151474, Omega_L = 0.7004724253456369, h = 0.6313673478485594
# Step 4987/5000: Current Chi^2 = 563.5405735664278, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1427835518151474, Omega_L = 0.7004724253456369, h = 0.6313673478485594
# Step 4988/5000: Current Chi^2 = 563.5405735664278, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1427835518151474, Omega_L = 0.7004724253456369, h = 0.6313673478485594
# Step 4989/5000: Current Chi^2 = 563.5405735664278, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1427835518151474, Omega_L = 0.7004724253456369, h = 0.6313673478485594
# Step 4990/5000: Current Chi^2 = 563.5405735664278, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.1427835518151474, Omega_L = 0.7004724253456369, h = 0.6313673478485594
# Step 4991/5000: Current Chi^2 = 563.5405735664278, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14120178522339127, Omega_L = 0.6967738877301002, h = 0.6232566333233255
# Step 4992/5000: Current Chi^2 = 565.4157502831631, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14662420124656325, Omega_L = 0.6972250752434753, h = 0.6302429168614111
# Step 4993/5000: Current Chi^2 = 565.1724696642668, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14662420124656325, Omega_L = 0.6972250752434753, h = 0.6302429168614111
# Step 4994/5000: Current Chi^2 = 565.1724696642668, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14662420124656325, Omega_L = 0.6972250752434753, h = 0.6302429168614111
# Step 4995/5000: Current Chi^2 = 565.1724696642668, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14662420124656325, Omega_L = 0.6972250752434753, h = 0.6302429168614111
# Step 4996/5000: Current Chi^2 = 565.1724696642668, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14655334068949064, Omega_L = 0.69649879613653, h = 0.6214067421594114
# Step 4997/5000: Current Chi^2 = 564.9481301814506, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14655334068949064, Omega_L = 0.69649879613653, h = 0.6214067421594114
# Step 4998/5000: Current Chi^2 = 564.9481301814506, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14655334068949064, Omega_L = 0.69649879613653, h = 0.6214067421594114
# Step 4999/5000: Current Chi^2 = 564.9481301814506, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14650335334902018, Omega_L = 0.6997363812691496, h = 0.6255895063996644
# Step 5000/5000: Current Chi^2 = 563.1330307905088, Best Chi^2 = 562.4574250507826
# Current Parameters: Omega_M = 0.14650335334902018, Omega_L = 0.6997363812691496, h = 0.6255895063996644
# Best parameters:
# Omega_M: 0.19653597417487229, Omega_L: 0.6996575049195541, h: 0.6549975584197816, Best Chi^2: 562.4574250507826

# %%
acceptence_ratio=accepted_steps/5000
print(acceptence_ratio)
# Out:
# 0.2698

# %% [markdown]
# One thing that i noticed after using logarithmic priors is that my acceptence ratio upped a bit, additionally the omega_m was able to walk throw the 0.01 np.random.normal like the other parameters unlike in my previous mcmc. However the omega m ratio is slightly lower that what is it predicted to be.

# %%
# Plotting chi-squared evolution
plt.plot(chi_squared_values)
plt.ylim(560,1000)
plt.xlim(100,5000)
plt.xlabel("Successful Step")
plt.ylabel("$\chi^{2}$")
plt.title("Evolution of $\chi^{2}$ over MCMC Steps")
plt.show()
print("Best parameters:")
print(f"Omega_M: {Omega_M_best}, Omega_L: {Omega_L_best}, h: {h_best}, Best Chi^2: {chi2_total_best}")
# Out:
# Best parameters:
# Omega_M: 0.19653597417487229, Omega_L: 0.6996575049195541, h: 0.6549975584197816, Best Chi^2: 562.4574250507826

# %%
import matplotlib.pyplot as plt
#Creatinf a plot that shows the trace of the different components and how they change as the chain keeps going
# Plot the trace for Omega_M
plt.figure(figsize=(10, 6))
plt.subplot(3, 1, 1)
plt.plot(Omega_M_list)
plt.xlabel("Step")
plt.ylabel("Omega_M")
plt.title("Trace Plot for Omega_M")

# Plot the trace for Omega_L
plt.subplot(3, 1, 2)
plt.plot(Omega_L_list)
plt.xlabel("Step")
plt.ylabel("Omega_L")
plt.title("Trace Plot for Omega_L")

# Plot the trace for h
plt.subplot(3, 1, 3)
plt.plot(h_list)
plt.xlabel("Step")
plt.ylabel("h")
plt.title("Trace Plot for h")

plt.tight_layout()
plt.show()

# %%
import numpy as np
from getdist import MCSamples, plots


#Removing the burn ins from the list
Omega_M_list=Omega_M_list[80:]
Omega_L_list=Omega_L_list[80:]
h_list=h_list[80:]
# converting the list to array
Omega_M = np.array(Omega_M_list)
Omega_L = np.array(Omega_L_list)
h = np.array(h_list)

# You can easily create new np.arrays that are functions of other np.arrays
Omega_k = 1. - Omega_M - Omega_L # calculating the omega k

# Let's define variable names and labels
my_labels = [r'h', r'\Omega_m', r'\Omega_\Lambda', r'\Omega_k']
my_names = ['h', 'Omega_M', 'Omega_L', 'Omega_k']
my_dim = len(my_names) # The number of variables we're plotting

# This creates a higher-dimensional array with all our data, shaped in the appropriate way...
my_samples = np.transpose(np.reshape([h, Omega_M, Omega_L, Omega_k], (my_dim, len(h))))

# ... to create an "MCSamples" data type, which GetDist can use
my_samples = MCSamples(samples=my_samples, labels=my_labels, names=my_names)

# The usual 1-sigma confidence level. You can change to 2- or 3-sigma if you want
conf_level = 0.6827

# This prints a table with the 1D posteriors (confidence levels)
for nam in my_names:
    print(round(my_samples.confidence(nam, (1. - conf_level) / 2., upper=False), 2), \
          " < ", nam , " < ", round(my_samples.confidence(nam, (1. - conf_level) / 2., upper=True), 2),\
          " at ", int(100 * conf_level), "\b% CL")
print("\n")

# Triangle corner plot
j = plots.getSubplotPlotter(subplot_size=3)
j.settings.axes_labelsize = 22
j.settings.axes_fontsize = 16
j.triangle_plot(my_samples, filled=True, title_limit=1, contour_colors=['purple'])
# Out:
# Removed no burn in
# % CL
# % CL
# % CL
# % CL
